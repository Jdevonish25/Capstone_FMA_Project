# %% [markdown]
# # Notebook 50: External Song Batch Testing with Full-Song Window Voting
#
# ## Purpose
#
# This notebook batch-tests external songs using the full-song window idea.
#
# Notebook 49 is the formal FMA benchmark. Notebook 50 is a deployment-style workflow: each external song is split into 15-second windows, each window is scored by the trained audio CNN, and song-level Top-1, Top-3, and Top-5 predictions are created from the average window scores plus window vote counts.
#
# ## Why Audio-Only Here?
#
# External songs do not have trusted FMA structured metadata rows. The cleanest deployment test is therefore the audio branch with full-song window voting. The formal hybrid benchmark remains in Notebook 49.
#
# ## Outputs
#
# - Song-level summary CSV
# - Candidate-level Top-N score CSV
# - Window-level prediction CSV
# - Error CSV
# - JSON run summary

# %%
# ============================================================
# Cell 1: Imports
# ============================================================

import os
import json
import math
import time
import tempfile
import subprocess
import warnings
from pathlib import Path
from datetime import datetime

import numpy as np
import pandas as pd

try:
    import librosa
except Exception as e:
    raise ImportError("librosa is required. Install with: pip install librosa") from e

try:
    import tensorflow as tf
    print("TensorFlow version:", tf.__version__)
except Exception as e:
    raise ImportError("TensorFlow could not be imported. Use the project .venv kernel.") from e

warnings.filterwarnings("ignore")
print("Imports completed.")
# Out:
# TensorFlow version: 2.20.0
# Imports completed.

# %%
# ============================================================
# Cell 2: User Settings
# ============================================================

PROJECT_ROOT = Path(r"E:\SCHOOL\Masters\Capstone_FMA_Project")
PROCESSED_DIR = PROJECT_ROOT / "data" / "processed"
MODELS_DIR = PROJECT_ROOT / "models"
METADATA_DIR = PROJECT_ROOT / "data" / "raw" / "metadata"

# Put songs in this folder, or change this path to your external-song folder.
EXTERNAL_AUDIO_DIR = PROJECT_ROOT / "data" / "external_audio_batch"
EXTERNAL_MANIFEST_XLSX_PATH = EXTERNAL_AUDIO_DIR / "external_audio_manifest.xlsx"
EXTERNAL_MANIFEST_CSV_PATH = EXTERNAL_AUDIO_DIR / "external_audio_manifest_source.csv"
REQUIRE_MANIFEST_FOR_EVALUATION = True

OUTPUT_DIR = PROJECT_ROOT / "outputs" / "notebook50_external_song_batch_windowed"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

AUDIO_EXTENSIONS = [".mp3", ".wav", ".flac", ".m4a", ".aac", ".ogg", ".wma", ".mp4", ".webm"]
MAX_FILES = None  # Example: 10 for a dry run, None for all files

# Full-song window settings.
WINDOW_SECONDS = 15
MAX_WINDOWS = 8
WINDOW_SELECTION_MODE = "evenly_spaced"  # "evenly_spaced" or "first_n"
LOOP_SHORT_AUDIO = True
LOOP_TARGET_SECONDS = WINDOW_SECONDS * min(MAX_WINDOWS, 4)

# Final audio/candidate settings.
STAGE1_THRESHOLD = 0.20
LOW_CONFIDENCE_THRESHOLD = 0.50
MIN_WINDOW_VOTES = 2
TOP_N_CANDIDATES = 15

# Audio CNN settings used during training.
SR = 22050
N_MELS = 64
N_FFT = 2048
HOP_LENGTH = 1024
MAX_FRAMES = int(np.ceil((WINDOW_SECONDS * SR) / HOP_LENGTH)) + 1

print("PROJECT_ROOT:", PROJECT_ROOT)
print("EXTERNAL_AUDIO_DIR:", EXTERNAL_AUDIO_DIR)
print("EXTERNAL_MANIFEST_XLSX_PATH:", EXTERNAL_MANIFEST_XLSX_PATH)
print("EXTERNAL_MANIFEST_CSV_PATH:", EXTERNAL_MANIFEST_CSV_PATH)
print("OUTPUT_DIR:", OUTPUT_DIR)
print("WINDOW_SECONDS:", WINDOW_SECONDS)
print("MAX_WINDOWS:", MAX_WINDOWS)
print("WINDOW_SELECTION_MODE:", WINDOW_SELECTION_MODE)
print("MIN_WINDOW_VOTES:", MIN_WINDOW_VOTES)
print("MAX_FRAMES:", MAX_FRAMES)
# Out:
# PROJECT_ROOT: E:\SCHOOL\Masters\Capstone_FMA_Project
# EXTERNAL_AUDIO_DIR: E:\SCHOOL\Masters\Capstone_FMA_Project\data\external_audio_batch
# EXTERNAL_MANIFEST_XLSX_PATH: E:\SCHOOL\Masters\Capstone_FMA_Project\data\external_audio_batch\external_audio_manifest.xlsx
# EXTERNAL_MANIFEST_CSV_PATH: E:\SCHOOL\Masters\Capstone_FMA_Project\data\external_audio_batch\external_audio_manifest_source.csv
# OUTPUT_DIR: E:\SCHOOL\Masters\Capstone_FMA_Project\outputs\notebook50_external_song_batch_windowed
# WINDOW_SECONDS: 15
# MAX_WINDOWS: 8
# WINDOW_SELECTION_MODE: evenly_spaced
# MIN_WINDOW_VOTES: 2
# MAX_FRAMES: 324

# %%
# ============================================================
# Cell 3: Load Frozen Audio Model and Label Metadata
# ============================================================

audio_model = tf.keras.models.load_model(
    MODELS_DIR / "audio_multilabel_candidate150_expanded_final.keras"
)

candidate_label_cols = np.load(
    PROCESSED_DIR / "hybrid_multilabel_candidate150_expanded_label_columns.npy",
    allow_pickle=True,
)
candidate_label_cols = [str(x) for x in candidate_label_cols.tolist()]
candidate_label_ids = [int(col.replace("genre_", "")) for col in candidate_label_cols]

genres_df = pd.read_csv(METADATA_DIR / "genres.csv")
if "genre_id" not in genres_df.columns:
    genres_df = genres_df.reset_index().rename(columns={"index": "genre_id"})
genres_df["genre_id"] = genres_df["genre_id"].astype(int)

id_to_name = dict(zip(genres_df["genre_id"], genres_df["title"].astype(str)))
id_to_parent = dict(zip(genres_df["genre_id"], genres_df.get("parent", pd.Series([0] * len(genres_df))).fillna(0).astype(int)))
id_to_top = dict(zip(genres_df["genre_id"], genres_df.get("top_level", genres_df["genre_id"]).fillna(genres_df["genre_id"]).astype(int)))

with open(PROCESSED_DIR / "audio_multilabel_candidate150_expanded_best_threshold.txt", "r") as f:
    audio_best_threshold = float(f.read().strip())

STAGE1_THRESHOLD = audio_best_threshold

print("Audio model input shape:", audio_model.input_shape)
print("Audio model output shape:", audio_model.output_shape)
print("Candidate labels:", len(candidate_label_cols))
print("Audio best threshold:", STAGE1_THRESHOLD)
print("First labels:", candidate_label_cols[:5])
# Out:
# Audio model input shape: (None, 64, 324, 1)
# Audio model output shape: (None, 150)
# Candidate labels: 150
# Audio best threshold: 0.2
# First labels: ['genre_1', 'genre_2', 'genre_3', 'genre_4', 'genre_5']

# %%
# ============================================================
# Cell 4: Helper Functions
# ============================================================

def timestamp_now():
    return datetime.now().strftime("%Y-%m-%d %H:%M:%S")


def genre_name_from_col(label_col):
    gid = int(str(label_col).replace("genre_", ""))
    return id_to_name.get(gid, str(gid))


def confidence_level(score):
    if score >= 0.70:
        return "High"
    if score >= 0.50:
        return "Moderate"
    if score >= 0.30:
        return "Low-to-moderate"
    return "Low"


def classify_relationship_to_main(genre_id, main_genre_id):
    if genre_id == main_genre_id:
        return "Primary genre"

    g_parent = id_to_parent.get(genre_id)
    g_root = id_to_top.get(genre_id)
    main_parent = id_to_parent.get(main_genre_id)
    main_root = id_to_top.get(main_genre_id)

    if g_parent == main_genre_id or g_root == main_genre_id:
        return "Subgenre/child under primary genre"
    if main_parent == genre_id or main_root == genre_id:
        return "Broader parent of primary genre"
    if g_root is not None and main_root is not None and g_root == main_root:
        return "Related genre in same top-level family"
    return "Secondary associated genre"


def load_audio_robust(file_path, sr=SR):
    try:
        y, sr_loaded = librosa.load(file_path, sr=sr, mono=True)
        if y is None or len(y) == 0:
            raise ValueError(f"Loaded audio is empty: {file_path}")
        return y, sr_loaded
    except Exception as first_error:
        ext = Path(file_path).suffix.lower()
        fallback_exts = {".mp4", ".m4a", ".aac", ".mov", ".3gp", ".webm", ".wma"}
        if ext not in fallback_exts:
            raise RuntimeError(f"Could not load audio file: {file_path}\nOriginal error: {first_error}")

        tmp_wav = None
        try:
            with tempfile.NamedTemporaryFile(suffix=".wav", delete=False) as tmp:
                tmp_wav = tmp.name
            cmd = ["ffmpeg", "-y", "-i", str(file_path), "-ac", "1", "-ar", str(sr), tmp_wav]
            result = subprocess.run(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
            if result.returncode != 0:
                raise RuntimeError(result.stderr)
            y, sr_loaded = librosa.load(tmp_wav, sr=sr, mono=True)
            if y is None or len(y) == 0:
                raise ValueError(f"Converted audio is empty: {file_path}")
            return y, sr_loaded
        finally:
            if tmp_wav:
                try:
                    os.remove(tmp_wav)
                except Exception:
                    pass


def loop_audio_if_needed(y, sr, target_seconds=LOOP_TARGET_SECONDS):
    target_len = int(target_seconds * sr)
    if not LOOP_SHORT_AUDIO or len(y) >= target_len:
        return y.astype(np.float32), False
    repeats = math.ceil(target_len / max(len(y), 1))
    return np.tile(y, repeats)[:target_len].astype(np.float32), True


def get_window_start_samples(y, sr=SR, window_seconds=WINDOW_SECONDS, max_windows=MAX_WINDOWS, mode=WINDOW_SELECTION_MODE):
    total_len = len(y)
    window_len = int(window_seconds * sr)
    if total_len <= window_len or max_windows <= 1:
        return [0]

    max_start = total_len - window_len
    if mode == "first_n":
        starts = []
        current = 0
        while current <= max_start and len(starts) < max_windows:
            starts.append(int(current))
            current += window_len
        return starts if starts else [0]

    if mode == "evenly_spaced":
        n_windows = min(max_windows, max(2, math.ceil(total_len / window_len)))
        starts = np.linspace(0, max_start, num=n_windows)
        return sorted(list(dict.fromkeys([int(x) for x in starts])))[:max_windows]

    raise ValueError("WINDOW_SELECTION_MODE must be 'evenly_spaced' or 'first_n'.")


def extract_window(y, start_sample, sr=SR, window_seconds=WINDOW_SECONDS):
    window_len = int(window_seconds * sr)
    segment = y[start_sample:start_sample + window_len]
    if len(segment) < window_len:
        segment = np.pad(segment, (0, window_len - len(segment)), mode="constant")
    return segment.astype(np.float32)


def build_mel_input(y_segment, sr=SR, n_mels=N_MELS, n_fft=N_FFT, hop_length=HOP_LENGTH, max_frames=MAX_FRAMES):
    mel = librosa.feature.melspectrogram(
        y=y_segment,
        sr=sr,
        n_fft=n_fft,
        hop_length=hop_length,
        n_mels=n_mels,
    )
    mel_db = librosa.power_to_db(mel, ref=np.max)
    mel_db = np.clip((mel_db + 80.0) / 80.0, 0.0, 1.0)

    if mel_db.shape[1] < max_frames:
        mel_db = np.pad(mel_db, ((0, 0), (0, max_frames - mel_db.shape[1])), mode="constant")
    else:
        mel_db = mel_db[:, :max_frames]

    return mel_db.astype(np.float32)[None, :, :, None]


def split_pipe_values(value):
    if value is None or (isinstance(value, float) and np.isnan(value)):
        return []
    parts = [str(x).strip() for x in str(value).split("|")]
    return [x for x in parts if x and x.lower() not in {"nan", "none"}]


def normalize_manifest_key(value):
    if value is None or (isinstance(value, float) and np.isnan(value)):
        return ""
    return str(value).replace("\\", "/").strip().lower()


def load_external_manifest(xlsx_path=EXTERNAL_MANIFEST_XLSX_PATH, csv_path=EXTERNAL_MANIFEST_CSV_PATH):
    manifest_path = None
    manifest_df = pd.DataFrame()

    # Prefer the CSV for notebook execution because it avoids optional Excel-engine dependencies.
    # The .xlsx workbook remains the human-readable manifest artifact.
    if Path(csv_path).exists():
        manifest_df = pd.read_csv(csv_path)
        manifest_path = Path(csv_path)

    if manifest_df.empty and Path(xlsx_path).exists():
        try:
            manifest_df = pd.read_excel(xlsx_path, sheet_name="Manifest")
            manifest_path = Path(xlsx_path)
        except Exception as e:
            print("Could not read Excel manifest. Install openpyxl or use the manifest CSV.")
            print("Excel read error:", e)

    if manifest_df.empty:
        print("No external manifest found. Notebook 50 will still predict audio files, but Top-k correctness cannot be evaluated.")
        return pd.DataFrame(), manifest_path

    required_cols = [
        "file_name",
        "relative_path",
        "local_path",
        "song_title",
        "artist",
        "expected_primary_genre",
        "acceptable_genres",
        "acceptable_labels",
        "source",
        "source_item_url",
        "source_file_url",
        "license_url",
    ]
    for col in required_cols:
        if col not in manifest_df.columns:
            manifest_df[col] = ""

    manifest_df["file_name"] = manifest_df["file_name"].fillna("").astype(str)
    manifest_df["relative_path"] = manifest_df["relative_path"].fillna("").astype(str)
    manifest_df["local_path"] = manifest_df["local_path"].fillna("").astype(str)
    manifest_df["file_name_key"] = manifest_df["file_name"].str.strip().str.lower()
    manifest_df["relative_path_key"] = manifest_df["relative_path"].apply(normalize_manifest_key)
    manifest_df["local_path_key"] = manifest_df["local_path"].apply(normalize_manifest_key)

    print("External manifest loaded:", manifest_path)
    print("Manifest rows:", len(manifest_df))
    if "expected_primary_genre" in manifest_df.columns:
        print("Manifest genre counts:")
        display(manifest_df["expected_primary_genre"].value_counts().rename_axis("genre").reset_index(name="songs"))

    return manifest_df, manifest_path


def resolve_manifest_audio_path(row):
    candidates = []

    local_path = str(row.get("local_path", "")).strip()
    relative_path = str(row.get("relative_path", "")).strip()
    file_name = str(row.get("file_name", "")).strip()

    if local_path and local_path.lower() not in {"nan", "none"}:
        candidates.append(Path(local_path))
    if relative_path and relative_path.lower() not in {"nan", "none"}:
        candidates.append(EXTERNAL_AUDIO_DIR / Path(relative_path.replace("/", os.sep)))
    if file_name and file_name.lower() not in {"nan", "none"}:
        candidates.append(EXTERNAL_AUDIO_DIR / file_name)

    for candidate in candidates:
        if candidate.exists():
            return candidate

    if file_name and file_name.lower() not in {"nan", "none"}:
        matches = list(EXTERNAL_AUDIO_DIR.rglob(file_name))
        if matches:
            return matches[0]

    return None

print("Helper functions ready.")
# Out:
# Helper functions ready.

# %%
# ============================================================
# Cell 5: Discover External Audio Files
# ============================================================

EXTERNAL_AUDIO_DIR.mkdir(parents=True, exist_ok=True)

manifest_df, manifest_path = load_external_manifest()
audio_manifest_df = pd.DataFrame()
missing_manifest_files = []

audio_files = []

if len(manifest_df):
    resolved_paths = []
    for _, row in manifest_df.iterrows():
        resolved = resolve_manifest_audio_path(row)
        if resolved is None:
            missing_manifest_files.append({
                "file_name": row.get("file_name", ""),
                "relative_path": row.get("relative_path", ""),
                "local_path": row.get("local_path", ""),
                "expected_primary_genre": row.get("expected_primary_genre", ""),
            })
            resolved_paths.append("")
        else:
            resolved_paths.append(str(resolved))
            audio_files.append(resolved)

    audio_manifest_df = manifest_df.copy()
    audio_manifest_df["resolved_audio_path"] = resolved_paths
    audio_manifest_df = audio_manifest_df[audio_manifest_df["resolved_audio_path"].astype(str).str.len() > 0].copy()

    if MAX_FILES is not None:
        audio_files = audio_files[:int(MAX_FILES)]
        keep_paths = {str(p) for p in audio_files}
        audio_manifest_df = audio_manifest_df[audio_manifest_df["resolved_audio_path"].isin(keep_paths)].copy()
else:
    for ext in AUDIO_EXTENSIONS:
        audio_files.extend(EXTERNAL_AUDIO_DIR.rglob(f"*{ext}"))
        audio_files.extend(EXTERNAL_AUDIO_DIR.rglob(f"*{ext.upper()}"))

    audio_files = sorted(set(audio_files))

    if MAX_FILES is not None:
        audio_files = audio_files[:int(MAX_FILES)]

print("External audio folder:", EXTERNAL_AUDIO_DIR)
print("Manifest used:", manifest_path)
print("Audio files selected:", len(audio_files))
print("Missing manifest files:", len(missing_manifest_files))

if missing_manifest_files:
    display(pd.DataFrame(missing_manifest_files).head(20))
    if REQUIRE_MANIFEST_FOR_EVALUATION:
        print("Warning: some manifest rows did not resolve to local audio files.")

if len(audio_files) == 0:
    print("Put audio files in EXTERNAL_AUDIO_DIR, then rerun from this cell.")
else:
    for p in audio_files[:20]:
        print("-", p.name)
# Out:
# External manifest loaded: E:\SCHOOL\Masters\Capstone_FMA_Project\data\external_audio_batch\external_audio_manifest_source.csv
# Manifest rows: 60
# Manifest genre counts:
#           genre  songs
# 0          Rock     10
# 1    Electronic     10
# 2  Experimental     10
# 3          Folk     10
# 4       Hip-Hop     10
# 5           Pop     10
# External audio folder: E:\SCHOOL\Masters\Capstone_FMA_Project\data\external_audio_batch
# Manifest used: E:\SCHOOL\Masters\Capstone_FMA_Project\data\external_audio_batch\external_audio_manifest_source.csv
# Audio files selected: 60
# Missing manifest files: 0
# - Rock__ca200_cjazz__503._Andrij_Orel_-_Ringo_Quartz.mp3
# - Rock__afm004_allmyfaults_neonoir__The_course_of_true_love_never_did_run_smooth__my_dearest.mp3
# - Rock__Lethargie.LP__Intro___Im_Herbst.mp3
# - Rock__Bostaurus.Demo__The_Sky_Full_of_Shadows.mp3
# - Rock__BS450014__Last_Addiction.mp3
# - Rock__csr020__Set_The_Controls_For_the_Heart_of_the_Sun.mp3
# - Rock__afm020_noctiflora_0407__Neorama.mp3
# - Rock__SCL160__Break_the_Lies__Gnothi_Seauton_Remix.mp3
# - Rock__freemusiccharts.songs2012__2012-01-H._Zombie-Taxi_Driver.mp3
# - Rock__diymAR06__10-Derek_Clegg-Judy.flac
# - Electronic__NS050__Lake.mp3
# - Electronic__mtk140__Csanca.mp3
# - Electronic__foot149__El_And_Eu.mp3
# - Electronic__nullbomb__spindrumlikeaboom.mp3
# - Electronic__TFR100-VA-TornFleshRecordsPresentsVestigialSickness__36_-_Vulgar_Disease_-_Every_Noise_Has_Its_TORN.mp3
# - Electronic__MIXG031__Vozduh.mp3
# - Electronic__pn037__Sabrina.mp3
# - Electronic__mtcomp003__latatoo__secede_s_another_day_wasted_mix.mp3
# - Electronic__ffs104__The_Leather.mp3
# - Electronic__foot018__Baiao_Lo-fi.mp3

# %%
# ============================================================
# Cell 6: Predict One Song with Full-Song Window Voting
# ============================================================

def predict_external_song(audio_path):
    audio_path = Path(audio_path)
    song_name = audio_path.stem
    file_name = audio_path.name
    try:
        relative_audio_path = str(audio_path.resolve().relative_to(EXTERNAL_AUDIO_DIR.resolve())).replace("\\", "/")
    except Exception:
        relative_audio_path = file_name

    y_original, sr_loaded = load_audio_robust(audio_path, sr=SR)
    original_duration = len(y_original) / sr_loaded

    y_for_inference, audio_was_looped = loop_audio_if_needed(
        y_original,
        sr=sr_loaded,
        target_seconds=LOOP_TARGET_SECONDS,
    )
    inference_duration = len(y_for_inference) / sr_loaded

    starts = get_window_start_samples(
        y_for_inference,
        sr=sr_loaded,
        window_seconds=WINDOW_SECONDS,
        max_windows=MAX_WINDOWS,
        mode=WINDOW_SELECTION_MODE,
    )

    window_rows = []
    window_prob_list = []

    for window_index, start_sample in enumerate(starts):
        segment = extract_window(y_for_inference, start_sample, sr=sr_loaded, window_seconds=WINDOW_SECONDS)
        X_audio = build_mel_input(
            segment,
            sr=sr_loaded,
            n_mels=N_MELS,
            n_fft=N_FFT,
            hop_length=HOP_LENGTH,
            max_frames=MAX_FRAMES,
        )
        probs = audio_model.predict(X_audio, verbose=0)[0]
        window_prob_list.append(probs)

        top_order = np.argsort(probs)[::-1]
        top1_idx = int(top_order[0])
        top3_idx = top_order[:3]
        top5_idx = top_order[:5]

        window_rows.append({
            "song_name": song_name,
            "audio_path": str(audio_path),
            "window_index": int(window_index),
            "start_sample": int(start_sample),
            "start_second": round(start_sample / sr_loaded, 2),
            "end_second": round((start_sample / sr_loaded) + WINDOW_SECONDS, 2),
            "top1_label": candidate_label_cols[top1_idx],
            "top1_genre_name": genre_name_from_col(candidate_label_cols[top1_idx]),
            "top1_score": float(probs[top1_idx]),
            "top3_labels": "|".join(candidate_label_cols[j] for j in top3_idx),
            "top3_genre_names": "|".join(genre_name_from_col(candidate_label_cols[j]) for j in top3_idx),
            "top5_labels": "|".join(candidate_label_cols[j] for j in top5_idx),
            "top5_genre_names": "|".join(genre_name_from_col(candidate_label_cols[j]) for j in top5_idx),
        })

    window_probs = np.vstack(window_prob_list)
    mean_scores = window_probs.mean(axis=0)
    max_scores = window_probs.max(axis=0)
    threshold_matrix = (window_probs >= STAGE1_THRESHOLD).astype(int)

    top1_per_window = np.argmax(window_probs, axis=1)
    top3_per_window = np.argsort(-window_probs, axis=1)[:, :3]
    top5_per_window = np.argsort(-window_probs, axis=1)[:, :5]

    required_window_votes = min(MIN_WINDOW_VOTES, len(starts))
    candidate_rows = []

    for j, label_col in enumerate(candidate_label_cols):
        genre_id = int(label_col.replace("genre_", ""))
        genre_name = genre_name_from_col(label_col)
        threshold_vote_count = int(threshold_matrix[:, j].sum())
        top1_vote_count = int(np.sum(top1_per_window == j))
        top3_vote_count = int(np.sum([j in row for row in top3_per_window]))
        top5_vote_count = int(np.sum([j in row for row in top5_per_window]))
        stable_prediction = int(
            (mean_scores[j] >= STAGE1_THRESHOLD)
            and (threshold_vote_count >= required_window_votes)
        )

        candidate_rows.append({
            "song_name": song_name,
            "audio_path": str(audio_path),
            "genre_id": genre_id,
            "label": label_col,
            "genre_name": genre_name,
            "mean_audio_score": float(mean_scores[j]),
            "max_audio_score": float(max_scores[j]),
            "confidence_level": confidence_level(float(mean_scores[j])),
            "threshold_vote_count": threshold_vote_count,
            "threshold_vote_rate": threshold_vote_count / len(starts),
            "top1_window_vote_count": top1_vote_count,
            "top3_window_vote_count": top3_vote_count,
            "top5_window_vote_count": top5_vote_count,
            "required_window_votes": required_window_votes,
            "stable_prediction": stable_prediction,
        })

    candidate_df = pd.DataFrame(candidate_rows).sort_values(
        ["mean_audio_score", "threshold_vote_count", "top3_window_vote_count"],
        ascending=[False, False, False],
    ).reset_index(drop=True)

    main_row = candidate_df.iloc[0].copy()
    main_genre_id = int(main_row["genre_id"])
    candidate_df["relationship_to_main"] = candidate_df["genre_id"].apply(
        lambda gid: classify_relationship_to_main(int(gid), main_genre_id)
    )

    top1 = candidate_df.head(1)
    top3 = candidate_df.head(3)
    top5 = candidate_df.head(5)
    predicted_df = candidate_df[candidate_df["stable_prediction"] == 1].copy()

    song_row = {
        "song_name": song_name,
        "file_name": file_name,
        "relative_path": relative_audio_path,
        "audio_path": str(audio_path),
        "status": "ok",
        "error": "",
        "original_duration_seconds": round(original_duration, 2),
        "inference_duration_seconds": round(inference_duration, 2),
        "audio_was_looped": bool(audio_was_looped),
        "windows_used": int(len(starts)),
        "window_seconds": WINDOW_SECONDS,
        "main_label": str(main_row["label"]),
        "main_genre_id": main_genre_id,
        "main_genre_name": str(main_row["genre_name"]),
        "main_score": float(main_row["mean_audio_score"]),
        "main_confidence_level": confidence_level(float(main_row["mean_audio_score"])),
        "main_threshold_vote_count": int(main_row["threshold_vote_count"]),
        "main_top1_window_vote_count": int(main_row["top1_window_vote_count"]),
        "main_top3_window_vote_count": int(main_row["top3_window_vote_count"]),
        "low_confidence": bool(float(main_row["mean_audio_score"]) < LOW_CONFIDENCE_THRESHOLD),
        "top1_labels": "|".join(top1["label"].astype(str).tolist()),
        "top1_genres": "|".join(top1["genre_name"].astype(str).tolist()),
        "top1_scores": "|".join(f"{x:.6f}" for x in top1["mean_audio_score"].tolist()),
        "top3_labels": "|".join(top3["label"].astype(str).tolist()),
        "top3_genres": "|".join(top3["genre_name"].astype(str).tolist()),
        "top3_scores": "|".join(f"{x:.6f}" for x in top3["mean_audio_score"].tolist()),
        "top5_labels": "|".join(top5["label"].astype(str).tolist()),
        "top5_genres": "|".join(top5["genre_name"].astype(str).tolist()),
        "top5_scores": "|".join(f"{x:.6f}" for x in top5["mean_audio_score"].tolist()),
        "stable_predicted_labels": "|".join(predicted_df["label"].astype(str).tolist()),
        "stable_predicted_genres": "|".join(predicted_df["genre_name"].astype(str).tolist()),
    }

    return song_row, candidate_df.head(TOP_N_CANDIDATES), pd.DataFrame(window_rows)

print("Prediction function ready.")
# Out:
# Prediction function ready.

# %%
# ============================================================
# Cell 7: Batch Prediction Loop
# ============================================================

song_rows = []
candidate_tables = []
window_tables = []
error_rows = []

start_time = time.time()

for idx, audio_path in enumerate(audio_files, start=1):
    print(f"[{idx}/{len(audio_files)}] Processing: {audio_path.name}")
    t0 = time.time()

    try:
        song_row, candidate_df, window_df = predict_external_song(audio_path)
        song_row["seconds"] = time.time() - t0
        song_rows.append(song_row)
        candidate_tables.append(candidate_df)
        window_tables.append(window_df)
    except Exception as e:
        error_row = {
            "song_name": Path(audio_path).stem,
            "file_name": Path(audio_path).name,
            "relative_path": str(Path(audio_path).name),
            "audio_path": str(audio_path),
            "status": "error",
            "error": str(e),
            "seconds": time.time() - t0,
        }
        song_rows.append(error_row)
        error_rows.append(error_row)
        print("  ERROR:", e)

song_summary_df = pd.DataFrame(song_rows)
candidate_results_df = pd.concat(candidate_tables, ignore_index=True) if candidate_tables else pd.DataFrame()
window_results_df = pd.concat(window_tables, ignore_index=True) if window_tables else pd.DataFrame()
error_df = pd.DataFrame(error_rows)

elapsed = time.time() - start_time

print("Batch completed.")
print("Songs attempted:", len(audio_files))
print("Successful songs:", int((song_summary_df.get("status", pd.Series(dtype=str)) == "ok").sum()) if len(song_summary_df) else 0)
print("Errors:", len(error_df))
print("Elapsed minutes:", round(elapsed / 60, 2))

display(song_summary_df.head(20))
# Out:
# [1/60] Processing: Rock__ca200_cjazz__503._Andrij_Orel_-_Ringo_Quartz.mp3
# [2/60] Processing: Rock__afm004_allmyfaults_neonoir__The_course_of_true_love_never_did_run_smooth__my_dearest.mp3
# [3/60] Processing: Rock__Lethargie.LP__Intro___Im_Herbst.mp3
# [4/60] Processing: Rock__Bostaurus.Demo__The_Sky_Full_of_Shadows.mp3
# [5/60] Processing: Rock__BS450014__Last_Addiction.mp3
# [6/60] Processing: Rock__csr020__Set_The_Controls_For_the_Heart_of_the_Sun.mp3
# [7/60] Processing: Rock__afm020_noctiflora_0407__Neorama.mp3
# [8/60] Processing: Rock__SCL160__Break_the_Lies__Gnothi_Seauton_Remix.mp3
# [9/60] Processing: Rock__freemusiccharts.songs2012__2012-01-H._Zombie-Taxi_Driver.mp3
# [10/60] Processing: Rock__diymAR06__10-Derek_Clegg-Judy.flac
# [11/60] Processing: Electronic__NS050__Lake.mp3
# [12/60] Processing: Electronic__mtk140__Csanca.mp3
# [13/60] Processing: Electronic__foot149__El_And_Eu.mp3
# [14/60] Processing: Electronic__nullbomb__spindrumlikeaboom.mp3
# [15/60] Processing: Electronic__TFR100-VA-TornFleshRecordsPresentsVestigialSickness__36_-_Vulgar_Disease_-_Every_Noise_Has_Its_TORN.mp3
# [16/60] Processing: Electronic__MIXG031__Vozduh.mp3
# [17/60] Processing: Electronic__pn037__Sabrina.mp3
# [18/60] Processing: Electronic__mtcomp003__latatoo__secede_s_another_day_wasted_mix.mp3
# [19/60] Processing: Electronic__ffs104__The_Leather.mp3
# [20/60] Processing: Electronic__foot018__Baiao_Lo-fi.mp3
# [21/60] Processing: Experimental__pcr089EmilDavydov-Sketches__Sketch_No.3.mp3
# [22/60] Processing: Experimental__PoodleplayArkestra-TheoryOfColour__Theory_Of_Colour.mp3
# [23/60] Processing: Experimental__ca446_opa__04_-_Russian_State_Museum_s_Lottery.mp3
# [24/60] Processing: Experimental__AlbumInADayVol4__Summer_Breeze.mp3
# [25/60] Processing: Experimental__ca350_g__sh-dah.mp3
# [26/60] Processing: Experimental__mz001_Mademoi_Selle__Himitsu.mp3
# [27/60] Processing: Experimental__tpd074__08_Grow_Up_Lamestream_Turd_Burglers.ogg
# [28/60] Processing: Experimental__ca492_ai__Beautiful_Distraction.mp3
# [29/60] Processing: Experimental__ca300_ca__206_-_Mons_Jacet_-_for_spring.mp3
# [30/60] Processing: Experimental__csr008__Say_Man.mp3
# [31/60] Processing: Folk__lbn016Plusplus-gameOver__04_Plusplus_-_Broken_Doors.mp3
# [32/60] Processing: Folk__lbn007NickRivera-happySongIsAHappySong__01_ReneeLuise.mp3
# [33/60] Processing: Folk__lbn017OldSplendifolia-utterlyHeartbreaking__Two_Eagles.mp3
# [34/60] Processing: Folk__EntertainmentForTheBraindead-Roadkillaaahh.009__Relapse.mp3
# [35/60] Processing: Folk__lclcb05DelgarmaDerAndrafolkWorldChanson__LCLCB05_-_Delgarma_-_Der_Andra_-_05_-_You_can_stay.mp3
# [36/60] Processing: Folk__pm007__The_Treeplanting_Song.mp3
# [37/60] Processing: Folk__pantoufle_tagada__I_Hope_You_re_Happy_With_Me.mp3
# [38/60] Processing: Folk__DDW001__02_-_Built_From_Sticks_-_Here_comes_the_circus.flac
# [39/60] Processing: Folk__ca201_meg__My_Orchard_Fire.mp3
# [40/60] Processing: Folk__ekleipsi23__system_1.mp3
# [41/60] Processing: Hip-Hop__DWK123__Soul_Key.mp3
# [42/60] Processing: Hip-Hop__DWK031__Aydio_-_01_-_Track.mp3
# [43/60] Processing: Hip-Hop__dystopiaq029__Times_re_Changin.mp3
# [44/60] Processing: Hip-Hop__DWK149__Boogieman_Penthouse.mp3
# [45/60] Processing: Hip-Hop__mia049__lifelong_fiction.mp3
# [46/60] Processing: Hip-Hop__DWK217__Morning_Mist.mp3
# [47/60] Processing: Hip-Hop__DWK301__Soul_Blue_Tango.mp3
# [48/60] Processing: Hip-Hop__DWK127__The_Werewolf.mp3
# [49/60] Processing: Hip-Hop__DWK315__Time2Spare.mp3
# [50/60] Processing: Hip-Hop__DWK155__Eazy_Livin.mp3
# [51/60] Processing: Pop__WkBw0034__01_-_Monochromatic_-_Immobility.mp3
# [52/60] Processing: Pop__BSOG0008__05_-_Doing_Time.mp3
# [53/60] Processing: Pop__starfrosch-mostwanted__Closer_to_You__feat._SHA.mp3
# [54/60] Processing: Pop__SCL129__Heaven_In_Your_Mouth.mp3
# [55/60] Processing: Pop__csr002__Falling.mp3
# [56/60] Processing: Pop__12rec.026__The_Virus_Left_Behind.mp3
# [57/60] Processing: Pop__iatmp3001__Blue_skies.mp3
# [58/60] Processing: Pop__BSCOMP0006__09_-_Universal_Materials_-_This_is_the_Macrophage.mp3
# [59/60] Processing: Pop__csr079__Runaway.mp3
# [60/60] Processing: Pop__mmm016__Mark_Robinson_-_Cape_May.flac
# Batch completed.
# Songs attempted: 60
# Successful songs: 60
# Errors: 0
# Elapsed minutes: 1.59
#                                             song_name  \
# 0   Rock__ca200_cjazz__503._Andrij_Orel_-_Ringo_Qu...
# 1   Rock__afm004_allmyfaults_neonoir__The_course_o...
# 2               Rock__Lethargie.LP__Intro___Im_Herbst
# 3       Rock__Bostaurus.Demo__The_Sky_Full_of_Shadows
# 4                      Rock__BS450014__Last_Addiction
# 5   Rock__csr020__Set_The_Controls_For_the_Heart_o...
# 6               Rock__afm020_noctiflora_0407__Neorama
# 7   Rock__SCL160__Break_the_Lies__Gnothi_Seauton_R...
# 8   Rock__freemusiccharts.songs2012__2012-01-H._Zo...
# 9                 Rock__diymAR06__10-Derek_Clegg-Judy
# 10                            Electronic__NS050__Lake
# 11                         Electronic__mtk140__Csanca
# 12                     Electronic__foot149__El_And_Eu
# 13            Electronic__nullbomb__spindrumlikeaboom
# 14  Electronic__TFR100-VA-TornFleshRecordsPresents...
# 15                        Electronic__MIXG031__Vozduh
# 16                         Electronic__pn037__Sabrina
# 17  Electronic__mtcomp003__latatoo__secede_s_anoth...
# 18                    Electronic__ffs104__The_Leather
# 19                   Electronic__foot018__Baiao_Lo-fi
#
#                                             file_name  \
# 0   Rock__ca200_cjazz__503._Andrij_Orel_-_Ringo_Qu...
# 1   Rock__afm004_allmyfaults_neonoir__The_course_o...
# 2           Rock__Lethargie.LP__Intro___Im_Herbst.mp3
# 3   Rock__Bostaurus.Demo__The_Sky_Full_of_Shadows.mp3
# 4                  Rock__BS450014__Last_Addiction.mp3
# 5   Rock__csr020__Set_The_Controls_For_the_Heart_o...
# 6           Rock__afm020_noctiflora_0407__Neorama.mp3
# 7   Rock__SCL160__Break_the_Lies__Gnothi_Seauton_R...
# 8   Rock__freemusiccharts.songs2012__2012-01-H._Zo...
# 9            Rock__diymAR06__10-Derek_Clegg-Judy.flac
# 10                        Electronic__NS050__Lake.mp3
# 11                     Electronic__mtk140__Csanca.mp3
# 12                 Electronic__foot149__El_And_Eu.mp3
# 13        Electronic__nullbomb__spindrumlikeaboom.mp3
# 14  Electronic__TFR100-VA-TornFleshRecordsPresents...
# 15                    Electronic__MIXG031__Vozduh.mp3
# 16                     Electronic__pn037__Sabrina.mp3
# 17  Electronic__mtcomp003__latatoo__secede_s_anoth...
# 18                Electronic__ffs104__The_Leather.mp3
# 19               Electronic__foot018__Baiao_Lo-fi.mp3
#
#                                         relative_path  \
# 0   Rock/Rock__ca200_cjazz__503._Andrij_Orel_-_Rin...
# 1   Rock/Rock__afm004_allmyfaults_neonoir__The_cou...
# 2      Rock/Rock__Lethargie.LP__Intro___Im_Herbst.mp3
# 3   Rock/Rock__Bostaurus.Demo__The_Sky_Full_of_Sha...
# 4             Rock/Rock__BS450014__Last_Addiction.mp3
# 5   Rock/Rock__csr020__Set_The_Controls_For_the_He...
# 6      Rock/Rock__afm020_noctiflora_0407__Neorama.mp3
# 7   Rock/Rock__SCL160__Break_the_Lies__Gnothi_Seau...
# 8   Rock/Rock__freemusiccharts.songs2012__2012-01-...
# 9       Rock/Rock__diymAR06__10-Derek_Clegg-Judy.flac
# 10             Electronic/Electronic__NS050__Lake.mp3
# 11          Electronic/Electronic__mtk140__Csanca.mp3
# 12      Electronic/Electronic__foot149__El_And_Eu.mp3
# 13  Electronic/Electronic__nullbomb__spindrumlikea...
# 14  Electronic/Electronic__TFR100-VA-TornFleshReco...
# 15         Electronic/Electronic__MIXG031__Vozduh.mp3
# 16          Electronic/Electronic__pn037__Sabrina.mp3
# 17  Electronic/Electronic__mtcomp003__latatoo__sec...
# 18     Electronic/Electronic__ffs104__The_Leather.mp3
# 19    Electronic/Electronic__foot018__Baiao_Lo-fi.mp3
#
#                                            audio_path status error  \
# 0   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...     ok
# 1   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...     ok
# 2   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...     ok
# 3   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...     ok
# 4   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...     ok
# 5   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...     ok
# 6   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...     ok
# 7   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...     ok
# 8   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...     ok
# 9   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...     ok
# 10  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...     ok
# 11  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...     ok
# 12  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...     ok
# 13  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...     ok
# 14  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...     ok
# 15  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...     ok
# 16  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...     ok
# 17  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...     ok
# 18  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...     ok
# 19  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...     ok
#
#     original_duration_seconds  inference_duration_seconds  audio_was_looped  \
# 0                      415.66                      415.66             False
# 1                      348.03                      348.03             False
# 2                      386.74                      386.74             False
# 3                      203.39                      203.39             False
# 4                      222.12                      222.12             False
# 5                      437.37                      437.37             False
# 6                      394.00                      394.00             False
# 7                      264.85                      264.85             False
# 8                      328.34                      328.34             False
# 9                      138.75                      138.75             False
# 10                     253.74                      253.74             False
# 11                     272.07                      272.07             False
# 12                     273.58                      273.58             False
# 13                     621.40                      621.40             False
# 14                     932.28                      932.28             False
# 15                     254.07                      254.07             False
# 16                     402.05                      402.05             False
# 17                     483.11                      483.11             False
# 18                     531.17                      531.17             False
# 19                     328.46                      328.46             False
#
#     windows_used  ...  top1_scores                   top3_labels  \
# 0              8  ...     0.565439    genre_38|genre_12|genre_17
# 1              8  ...     0.578539    genre_38|genre_12|genre_15
# 2              8  ...     0.612928    genre_38|genre_15|genre_12
# 3              8  ...     0.558755    genre_38|genre_12|genre_15
# 4              8  ...     0.481872    genre_12|genre_17|genre_38
# 5              8  ...     0.487924    genre_38|genre_12|genre_17
# 6              8  ...     0.546284    genre_38|genre_12|genre_15
# 7              8  ...     0.606244    genre_38|genre_15|genre_12
# 8              8  ...     0.630960    genre_15|genre_38|genre_12
# 9              8  ...     0.390207    genre_12|genre_38|genre_10
# 10             8  ...     0.468257    genre_38|genre_12|genre_17
# 11             8  ...     0.380607    genre_15|genre_38|genre_12
# 12             8  ...     0.389795    genre_12|genre_38|genre_15
# 13             8  ...     0.536827    genre_15|genre_38|genre_12
# 14             8  ...     0.776628    genre_38|genre_15|genre_32
# 15             8  ...     0.456272    genre_12|genre_38|genre_15
# 16             8  ...     0.561783  genre_38|genre_15|genre_1235
# 17             8  ...     0.543909  genre_38|genre_15|genre_1235
# 18             8  ...     0.562499    genre_38|genre_12|genre_15
# 19             8  ...     0.489454    genre_38|genre_15|genre_12
#
#                              top3_genres                 top3_scores  \
# 0                 Experimental|Rock|Folk  0.565439|0.265028|0.200406
# 1           Experimental|Rock|Electronic  0.578539|0.325567|0.296563
# 2           Experimental|Electronic|Rock  0.612928|0.399678|0.270417
# 3           Experimental|Rock|Electronic  0.558755|0.414183|0.279063
# 4                 Rock|Folk|Experimental  0.481872|0.392524|0.359924
# 5                 Experimental|Rock|Folk  0.487924|0.461642|0.180819
# 6           Experimental|Rock|Electronic  0.546284|0.332376|0.263510
# 7           Experimental|Electronic|Rock  0.606244|0.347760|0.228466
# 8           Electronic|Experimental|Rock  0.630960|0.396147|0.252419
# 9                  Rock|Experimental|Pop  0.390207|0.311216|0.262928
# 10                Experimental|Rock|Folk  0.468257|0.321593|0.304552
# 11          Electronic|Experimental|Rock  0.380607|0.362406|0.308745
# 12          Rock|Experimental|Electronic  0.389795|0.356129|0.285443
# 13          Electronic|Experimental|Rock  0.536827|0.515805|0.217403
# 14         Experimental|Electronic|Noise  0.776628|0.413171|0.180288
# 15          Rock|Experimental|Electronic  0.456272|0.425772|0.247722
# 16  Experimental|Electronic|Instrumental  0.561783|0.557847|0.208064
# 17  Experimental|Electronic|Instrumental  0.543909|0.438383|0.238347
# 18          Experimental|Rock|Electronic  0.562499|0.295575|0.284637
# 19          Experimental|Electronic|Rock  0.489454|0.453861|0.274992
#
#                                         top5_labels  \
# 0   genre_38|genre_12|genre_17|genre_250|genre_1235
# 1       genre_38|genre_12|genre_15|genre_1|genre_10
# 2       genre_38|genre_15|genre_12|genre_1|genre_32
# 3       genre_38|genre_12|genre_15|genre_25|genre_1
# 4     genre_12|genre_17|genre_38|genre_10|genre_103
# 5      genre_38|genre_12|genre_17|genre_15|genre_10
# 6    genre_38|genre_12|genre_15|genre_1235|genre_17
# 7     genre_38|genre_15|genre_12|genre_1|genre_1235
# 8    genre_15|genre_38|genre_12|genre_1235|genre_21
# 9      genre_12|genre_38|genre_10|genre_15|genre_17
# 10   genre_38|genre_12|genre_17|genre_10|genre_1235
# 11     genre_15|genre_38|genre_12|genre_10|genre_17
# 12     genre_12|genre_38|genre_15|genre_21|genre_10
# 13   genre_15|genre_38|genre_12|genre_21|genre_1235
# 14      genre_38|genre_15|genre_32|genre_1|genre_12
# 15     genre_12|genre_38|genre_15|genre_10|genre_17
# 16   genre_38|genre_15|genre_1235|genre_12|genre_10
# 17  genre_38|genre_15|genre_1235|genre_12|genre_107
# 18      genre_38|genre_12|genre_15|genre_1|genre_21
# 19   genre_38|genre_15|genre_12|genre_21|genre_1235
#
#                                           top5_genres  \
# 0          Experimental|Rock|Folk|Improv|Instrumental
# 1        Experimental|Rock|Electronic|Avant-Garde|Pop
# 2      Experimental|Electronic|Rock|Avant-Garde|Noise
# 3       Experimental|Rock|Electronic|Punk|Avant-Garde
# 4        Rock|Folk|Experimental|Pop|Singer-Songwriter
# 5               Experimental|Rock|Folk|Electronic|Pop
# 6      Experimental|Rock|Electronic|Instrumental|Folk
# 7   Experimental|Electronic|Rock|Avant-Garde|Instr...
# 8   Electronic|Experimental|Rock|Instrumental|Hip-Hop
# 9               Rock|Experimental|Pop|Electronic|Folk
# 10            Experimental|Rock|Folk|Pop|Instrumental
# 11              Electronic|Experimental|Rock|Pop|Folk
# 12           Rock|Experimental|Electronic|Hip-Hop|Pop
# 13  Electronic|Experimental|Rock|Hip-Hop|Instrumental
# 14     Experimental|Electronic|Noise|Avant-Garde|Rock
# 15              Rock|Experimental|Electronic|Pop|Folk
# 16      Experimental|Electronic|Instrumental|Rock|Pop
# 17  Experimental|Electronic|Instrumental|Rock|Ambient
# 18   Experimental|Rock|Electronic|Avant-Garde|Hip-Hop
# 19  Experimental|Electronic|Rock|Hip-Hop|Instrumental
#
#                                      top5_scores  \
# 0   0.565439|0.265028|0.200406|0.199195|0.165079
# 1   0.578539|0.325567|0.296563|0.133387|0.123368
# 2   0.612928|0.399678|0.270417|0.111470|0.109929
# 3   0.558755|0.414183|0.279063|0.165451|0.113199
# 4   0.481872|0.392524|0.359924|0.221322|0.177411
# 5   0.487924|0.461642|0.180819|0.152037|0.139754
# 6   0.546284|0.332376|0.263510|0.191842|0.134067
# 7   0.606244|0.347760|0.228466|0.130879|0.128252
# 8   0.630960|0.396147|0.252419|0.165456|0.163194
# 9   0.390207|0.311216|0.262928|0.244625|0.224317
# 10  0.468257|0.321593|0.304552|0.154378|0.132731
# 11  0.380607|0.362406|0.308745|0.242587|0.146406
# 12  0.389795|0.356129|0.285443|0.181627|0.154438
# 13  0.536827|0.515805|0.217403|0.169662|0.116522
# 14  0.776628|0.413171|0.180288|0.157284|0.147681
# 15  0.456272|0.425772|0.247722|0.215524|0.137419
# 16  0.561783|0.557847|0.208064|0.165057|0.110032
# 17  0.543909|0.438383|0.238347|0.195952|0.118249
# 18  0.562499|0.295575|0.284637|0.142081|0.137169
# 19  0.489454|0.453861|0.274992|0.162977|0.127129
#
#                          stable_predicted_labels  \
# 0                     genre_38|genre_12|genre_17
# 1                     genre_38|genre_12|genre_15
# 2                     genre_38|genre_15|genre_12
# 3                     genre_38|genre_12|genre_15
# 4            genre_12|genre_17|genre_38|genre_10
# 5                              genre_38|genre_12
# 6                     genre_38|genre_12|genre_15
# 7                     genre_38|genre_15|genre_12
# 8                     genre_15|genre_38|genre_12
# 9   genre_12|genre_38|genre_10|genre_15|genre_17
# 10                    genre_38|genre_12|genre_17
# 11           genre_15|genre_38|genre_12|genre_10
# 12                    genre_12|genre_38|genre_15
# 13                    genre_15|genre_38|genre_12
# 14                             genre_38|genre_15
# 15           genre_12|genre_38|genre_15|genre_10
# 16                  genre_38|genre_15|genre_1235
# 17                  genre_38|genre_15|genre_1235
# 18                    genre_38|genre_12|genre_15
# 19                    genre_38|genre_15|genre_12
#
#                   stable_predicted_genres   seconds
# 0                  Experimental|Rock|Folk  4.579049
# 1            Experimental|Rock|Electronic  1.605244
# 2            Experimental|Electronic|Rock  1.704806
# 3            Experimental|Rock|Electronic  1.291217
# 4              Rock|Folk|Experimental|Pop  1.389459
# 5                       Experimental|Rock  1.593828
# 6            Experimental|Rock|Electronic  1.646167
# 7            Experimental|Electronic|Rock  1.586464
# 8            Electronic|Experimental|Rock  1.615341
# 9   Rock|Experimental|Pop|Electronic|Folk  1.347060
# 10                 Experimental|Rock|Folk  1.512982
# 11       Electronic|Experimental|Rock|Pop  1.448907
# 12           Rock|Experimental|Electronic  1.710017
# 13           Electronic|Experimental|Rock  2.154215
# 14                Experimental|Electronic  2.751693
# 15       Rock|Experimental|Electronic|Pop  1.417097
# 16   Experimental|Electronic|Instrumental  1.684835
# 17   Experimental|Electronic|Instrumental  1.794133
# 18           Experimental|Rock|Electronic  1.803460
# 19           Experimental|Electronic|Rock  1.390327
#
# [20 rows x 32 columns]

# %%
# ============================================================
# Cell 8: Evaluate Predictions Against External Manifest
# ============================================================

manifest_eval_df = pd.DataFrame()
manifest_eval_summary_by_genre_df = pd.DataFrame()
manifest_overall_metrics = {}

def labels_intersect(predicted_labels, acceptable_labels):
    predicted = set(split_pipe_values(predicted_labels))
    acceptable = set(split_pipe_values(acceptable_labels))
    return bool(predicted and acceptable and predicted.intersection(acceptable))


if len(song_summary_df) == 0:
    print("No song predictions to evaluate yet.")
elif "manifest_df" not in globals() or len(manifest_df) == 0:
    print("No manifest loaded. Predictions were produced, but Top-k correctness cannot be evaluated.")
else:
    ok_summary = song_summary_df[song_summary_df["status"].astype(str).str.lower() == "ok"].copy()
    if len(ok_summary) == 0:
        print("No successful predictions to evaluate.")
    else:
        manifest_for_merge = manifest_df.copy()
        for col in [
            "file_name",
            "song_title",
            "artist",
            "expected_primary_genre",
            "acceptable_genres",
            "acceptable_labels",
            "source",
            "source_item_url",
            "source_file_url",
            "license_url",
        ]:
            if col not in manifest_for_merge.columns:
                manifest_for_merge[col] = ""

        ok_summary["file_name_key"] = ok_summary["file_name"].fillna("").astype(str).str.strip().str.lower()
        manifest_for_merge["file_name_key"] = manifest_for_merge["file_name"].fillna("").astype(str).str.strip().str.lower()

        manifest_cols = [
            "file_name_key",
            "song_title",
            "artist",
            "expected_primary_genre",
            "acceptable_genres",
            "acceptable_labels",
            "source",
            "source_item_url",
            "source_file_url",
            "license_url",
        ]

        manifest_eval_df = ok_summary.merge(
            manifest_for_merge[manifest_cols],
            on="file_name_key",
            how="left",
            suffixes=("", "_manifest"),
        )

        manifest_eval_df["manifest_matched"] = manifest_eval_df["acceptable_labels"].fillna("").astype(str).str.len() > 0
        manifest_eval_df["top1_hit"] = manifest_eval_df.apply(
            lambda row: labels_intersect(row.get("top1_labels", row.get("main_label", "")), row.get("acceptable_labels", "")),
            axis=1,
        )
        manifest_eval_df["top3_hit"] = manifest_eval_df.apply(
            lambda row: labels_intersect(row.get("top3_labels", ""), row.get("acceptable_labels", "")),
            axis=1,
        )
        manifest_eval_df["top5_hit"] = manifest_eval_df.apply(
            lambda row: labels_intersect(row.get("top5_labels", ""), row.get("acceptable_labels", "")),
            axis=1,
        )
        manifest_eval_df["stable_prediction_hit"] = manifest_eval_df.apply(
            lambda row: labels_intersect(row.get("stable_predicted_labels", ""), row.get("acceptable_labels", "")),
            axis=1,
        )
        manifest_eval_df["expected_primary_name_top1_exact"] = (
            manifest_eval_df["main_genre_name"].fillna("").astype(str).str.lower().str.strip()
            == manifest_eval_df["expected_primary_genre"].fillna("").astype(str).str.lower().str.strip()
        )

        eval_base = manifest_eval_df[manifest_eval_df["manifest_matched"]].copy()
        if len(eval_base):
            manifest_eval_summary_by_genre_df = eval_base.groupby("expected_primary_genre", dropna=False).agg(
                songs=("song_name", "count"),
                top1_hit_rate=("top1_hit", "mean"),
                top3_hit_rate=("top3_hit", "mean"),
                top5_hit_rate=("top5_hit", "mean"),
                stable_prediction_hit_rate=("stable_prediction_hit", "mean"),
                exact_expected_name_top1_rate=("expected_primary_name_top1_exact", "mean"),
                avg_main_score=("main_score", "mean"),
                low_confidence_rate=("low_confidence", "mean"),
            ).reset_index()

            manifest_overall_metrics = {
                "songs_evaluated_with_manifest": int(len(eval_base)),
                "top1_hit_rate": float(eval_base["top1_hit"].mean()),
                "top3_hit_rate": float(eval_base["top3_hit"].mean()),
                "top5_hit_rate": float(eval_base["top5_hit"].mean()),
                "stable_prediction_hit_rate": float(eval_base["stable_prediction_hit"].mean()),
                "exact_expected_name_top1_rate": float(eval_base["expected_primary_name_top1_exact"].mean()),
                "avg_main_score": float(eval_base["main_score"].mean()),
                "low_confidence_rate": float(eval_base["low_confidence"].mean()),
            }

            print("Manifest-evaluated songs:", manifest_overall_metrics["songs_evaluated_with_manifest"])
            print("Top-1 hit rate:", round(manifest_overall_metrics["top1_hit_rate"], 3))
            print("Top-3 hit rate:", round(manifest_overall_metrics["top3_hit_rate"], 3))
            print("Top-5 hit rate:", round(manifest_overall_metrics["top5_hit_rate"], 3))
            print("Stable prediction hit rate:", round(manifest_overall_metrics["stable_prediction_hit_rate"], 3))

            display(manifest_eval_summary_by_genre_df)

            print("\nMiss cases where acceptable genre was not in Top-5:")
            miss_cols = [
                "song_title",
                "artist",
                "expected_primary_genre",
                "acceptable_genres",
                "main_genre_name",
                "main_score",
                "top3_genres",
                "top5_genres",
                "top5_hit",
                "low_confidence",
            ]
            display(eval_base.loc[~eval_base["top5_hit"], [c for c in miss_cols if c in eval_base.columns]].head(30))
        else:
            print("Predictions ran, but no rows matched the manifest.")
# Out:
# Manifest-evaluated songs: 60
# Top-1 hit rate: 0.217
# Top-3 hit rate: 0.667
# Top-5 hit rate: 0.833
# Stable prediction hit rate: 0.667
#   expected_primary_genre  songs  top1_hit_rate  top3_hit_rate  top5_hit_rate  \
# 0             Electronic     10            0.2            0.9            0.9
# 1           Experimental     10            0.6            1.0            1.0
# 2                   Folk     10            0.2            0.7            0.7
# 3                Hip-Hop     10            0.1            0.4            0.7
# 4                    Pop     10            0.0            0.0            0.7
# 5                   Rock     10            0.2            1.0            1.0
#
#    stable_prediction_hit_rate  exact_expected_name_top1_rate  avg_main_score  \
# 0                         0.9                            0.2        0.516603
# 1                         1.0                            0.6        0.502761
# 2                         0.7                            0.2        0.497679
# 3                         0.4                            0.1        0.480389
# 4                         0.0                            0.0        0.527450
# 5                         1.0                            0.2        0.545915
#
#    low_confidence_rate
# 0                  0.5
# 1                  0.5
# 2                  0.6
# 3                  0.7
# 4                  0.3
# 5                  0.3
# Miss cases where acceptable genre was not in Top-5:
#                      song_title                             artist  \
# 10                         Lake                 No-Source Netlabel
# 30   04 Plusplus - Broken Doors                                NaN
# 36  I Hope You're Happy With Me                                NaN
# 39                     system 1                    Various Artists
# 41                  Deltitnu EP                              Aydio
# 45                 Morning Mist                    Boogie Belgique
# 48                   Time2Spare                             Anitek
# 56                   Blue skies  Bjorn Kleinhenz and Pete Thompson
# 58                      Runaway                                NaN
# 59     Mark Robinson - Cape May          My Mean Magpie Recordings
#
#    expected_primary_genre                                  acceptable_genres  \
# 10             Electronic  Electronic|Ambient Electronic|IDM|Glitch|Techn...
# 30                   Folk  Folk|Singer-Songwriter|Psych-Folk|Freak-Folk|F...
# 36                   Folk  Folk|Singer-Songwriter|Psych-Folk|Freak-Folk|F...
# 39                   Folk  Folk|Singer-Songwriter|Psych-Folk|Freak-Folk|F...
# 41                Hip-Hop  Hip-Hop|Hip-Hop Beats|Alternative Hip-Hop|Rap|...
# 45                Hip-Hop  Hip-Hop|Hip-Hop Beats|Alternative Hip-Hop|Rap|...
# 48                Hip-Hop  Hip-Hop|Hip-Hop Beats|Alternative Hip-Hop|Rap|...
# 56                    Pop           Pop|Experimental Pop|Synth Pop|Power-Pop
# 58                    Pop           Pop|Experimental Pop|Synth Pop|Power-Pop
# 59                    Pop           Pop|Experimental Pop|Synth Pop|Power-Pop
#
#    main_genre_name  main_score                      top3_genres  \
# 10    Experimental    0.468257           Experimental|Rock|Folk
# 30    Experimental    0.434638     Experimental|Electronic|Rock
# 36      Electronic    0.687244  Electronic|Experimental|Hip-Hop
# 39    Experimental    0.555550     Experimental|Electronic|Rock
# 41    Experimental    0.554200     Experimental|Electronic|Rock
# 45            Rock    0.394960     Rock|Experimental|Electronic
# 48    Experimental    0.620664     Experimental|Electronic|Rock
# 56    Experimental    0.551967     Experimental|Rock|Electronic
# 58    Experimental    0.524945     Experimental|Rock|Electronic
# 59    Experimental    0.498985           Experimental|Rock|Punk
#
#                                           top5_genres  top5_hit  \
# 10            Experimental|Rock|Folk|Pop|Instrumental     False
# 30      Experimental|Electronic|Rock|Pop|Instrumental     False
# 36  Electronic|Experimental|Hip-Hop|Instrumental|Rock     False
# 39      Experimental|Electronic|Rock|Instrumental|Pop     False
# 41      Experimental|Electronic|Rock|Instrumental|Pop     False
# 45      Rock|Experimental|Electronic|Pop|Instrumental     False
# 48  Experimental|Electronic|Rock|Instrumental|Avan...     False
# 56      Experimental|Rock|Electronic|Folk|Avant-Garde     False
# 58      Experimental|Rock|Electronic|Avant-Garde|Folk     False
# 59           Experimental|Rock|Punk|Avant-Garde|Lo-Fi     False
#
#     low_confidence
# 10            True
# 30            True
# 36           False
# 39           False
# 41           False
# 45            True
# 48           False
# 56           False
# 58           False
# 59            True

# %%
# ============================================================
# Cell 9: Save Outputs
# ============================================================

OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
import importlib.util

song_summary_path = OUTPUT_DIR / "notebook50_external_song_summary.csv"
candidate_results_path = OUTPUT_DIR / "notebook50_external_candidate_scores_topn.csv"
window_results_path = OUTPUT_DIR / "notebook50_external_window_predictions.csv"
error_path = OUTPUT_DIR / "notebook50_external_errors.csv"
manifest_eval_path = OUTPUT_DIR / "notebook50_external_manifest_evaluation.csv"
manifest_eval_summary_path = OUTPUT_DIR / "notebook50_external_manifest_evaluation_by_genre.csv"
manifest_eval_xlsx_path = OUTPUT_DIR / "notebook50_external_manifest_evaluation.xlsx"
json_path = OUTPUT_DIR / "notebook50_external_batch_summary.json"

song_summary_df.to_csv(song_summary_path, index=False)
candidate_results_df.to_csv(candidate_results_path, index=False)
window_results_df.to_csv(window_results_path, index=False)
error_df.to_csv(error_path, index=False)

if "manifest_eval_df" not in globals():
    manifest_eval_df = pd.DataFrame()
if "manifest_eval_summary_by_genre_df" not in globals():
    manifest_eval_summary_by_genre_df = pd.DataFrame()
if "manifest_overall_metrics" not in globals():
    manifest_overall_metrics = {}

manifest_eval_df.to_csv(manifest_eval_path, index=False)
manifest_eval_summary_by_genre_df.to_csv(manifest_eval_summary_path, index=False)

manifest_eval_xlsx_saved = ""
if len(manifest_eval_df):
    if importlib.util.find_spec("openpyxl") is None:
        print("openpyxl is not installed, so the optional Excel evaluation workbook was skipped. CSV outputs were saved.")
    else:
        try:
            with pd.ExcelWriter(manifest_eval_xlsx_path, engine="openpyxl") as writer:
                manifest_eval_df.to_excel(writer, sheet_name="Song Evaluation", index=False)
                manifest_eval_summary_by_genre_df.to_excel(writer, sheet_name="By Genre", index=False)
                song_summary_df.to_excel(writer, sheet_name="Song Predictions", index=False)
            manifest_eval_xlsx_saved = str(manifest_eval_xlsx_path)
        except Exception as e:
            print("Could not save Excel evaluation workbook; CSV outputs were saved.")
            print("Excel writer error:", e)

summary = {
    "created_at": timestamp_now(),
    "notebook": "50_external_song_batch_windowed_inference.ipynb",
    "external_audio_dir": str(EXTERNAL_AUDIO_DIR),
    "output_dir": str(OUTPUT_DIR),
    "songs_attempted": int(len(audio_files)),
    "successful_songs": int((song_summary_df.get("status", pd.Series(dtype=str)) == "ok").sum()) if len(song_summary_df) else 0,
    "error_songs": int(len(error_df)),
    "window_seconds": WINDOW_SECONDS,
    "max_windows": MAX_WINDOWS,
    "window_selection_mode": WINDOW_SELECTION_MODE,
    "min_window_votes": MIN_WINDOW_VOTES,
    "stage1_threshold": STAGE1_THRESHOLD,
    "external_manifest_xlsx": str(EXTERNAL_MANIFEST_XLSX_PATH),
    "external_manifest_csv": str(EXTERNAL_MANIFEST_CSV_PATH),
    "manifest_source_used": str(manifest_path) if "manifest_path" in globals() and manifest_path is not None else "",
    "manifest_rows": int(len(manifest_df)) if "manifest_df" in globals() else 0,
    "manifest_overall_metrics": manifest_overall_metrics,
    "outputs": {
        "song_summary": str(song_summary_path),
        "candidate_scores_topn": str(candidate_results_path),
        "window_predictions": str(window_results_path),
        "errors": str(error_path),
        "manifest_evaluation": str(manifest_eval_path),
        "manifest_evaluation_by_genre": str(manifest_eval_summary_path),
        "manifest_evaluation_xlsx": manifest_eval_xlsx_saved,
    },
}

with open(json_path, "w", encoding="utf-8") as f:
    json.dump(summary, f, indent=2)

print("Saved outputs:")
for key, value in summary["outputs"].items():
    print(f"{key}: {value}")
print("summary_json:", json_path)
# Out:
# openpyxl is not installed, so the optional Excel evaluation workbook was skipped. CSV outputs were saved.
# Saved outputs:
# song_summary: E:\SCHOOL\Masters\Capstone_FMA_Project\outputs\notebook50_external_song_batch_windowed\notebook50_external_song_summary.csv
# candidate_scores_topn: E:\SCHOOL\Masters\Capstone_FMA_Project\outputs\notebook50_external_song_batch_windowed\notebook50_external_candidate_scores_topn.csv
# window_predictions: E:\SCHOOL\Masters\Capstone_FMA_Project\outputs\notebook50_external_song_batch_windowed\notebook50_external_window_predictions.csv
# errors: E:\SCHOOL\Masters\Capstone_FMA_Project\outputs\notebook50_external_song_batch_windowed\notebook50_external_errors.csv
# manifest_evaluation: E:\SCHOOL\Masters\Capstone_FMA_Project\outputs\notebook50_external_song_batch_windowed\notebook50_external_manifest_evaluation.csv
# manifest_evaluation_by_genre: E:\SCHOOL\Masters\Capstone_FMA_Project\outputs\notebook50_external_song_batch_windowed\notebook50_external_manifest_evaluation_by_genre.csv
# manifest_evaluation_xlsx:
# summary_json: E:\SCHOOL\Masters\Capstone_FMA_Project\outputs\notebook50_external_song_batch_windowed\notebook50_external_batch_summary.json

# %%
# ============================================================
# Cell 10: Review Tables
# ============================================================

print("Song-level predictions:")
if len(song_summary_df):
    review_cols = [
        "song_name",
        "main_genre_name",
        "main_score",
        "main_confidence_level",
        "main_threshold_vote_count",
        "main_top1_window_vote_count",
        "main_top3_window_vote_count",
        "top3_genres",
        "top5_genres",
        "low_confidence",
    ]
    available_cols = [c for c in review_cols if c in song_summary_df.columns]
    display(song_summary_df[available_cols].head(50))
else:
    print("No songs processed yet.")

print("\nTop candidate rows:")
display(candidate_results_df.head(50))

print("\nWindow-level predictions:")
display(window_results_df.head(50))

if len(error_df):
    print("\nErrors:")
    display(error_df)


print("\nManifest evaluation by genre:")
if "manifest_eval_summary_by_genre_df" in globals() and len(manifest_eval_summary_by_genre_df):
    display(manifest_eval_summary_by_genre_df)
else:
    print("No manifest evaluation summary available.")

print("\nManifest-evaluated song rows:")
if "manifest_eval_df" in globals() and len(manifest_eval_df):
    eval_review_cols = [
        "song_title",
        "artist",
        "expected_primary_genre",
        "main_genre_name",
        "main_score",
        "top1_hit",
        "top3_hit",
        "top5_hit",
        "stable_prediction_hit",
        "top3_genres",
        "top5_genres",
    ]
    display(manifest_eval_df[[c for c in eval_review_cols if c in manifest_eval_df.columns]].head(60))
else:
    print("No manifest evaluation rows available.")
# Out:
# Song-level predictions:
#                                             song_name main_genre_name  \
# 0   Rock__ca200_cjazz__503._Andrij_Orel_-_Ringo_Qu...    Experimental
# 1   Rock__afm004_allmyfaults_neonoir__The_course_o...    Experimental
# 2               Rock__Lethargie.LP__Intro___Im_Herbst    Experimental
# 3       Rock__Bostaurus.Demo__The_Sky_Full_of_Shadows    Experimental
# 4                      Rock__BS450014__Last_Addiction            Rock
# 5   Rock__csr020__Set_The_Controls_For_the_Heart_o...    Experimental
# 6               Rock__afm020_noctiflora_0407__Neorama    Experimental
# 7   Rock__SCL160__Break_the_Lies__Gnothi_Seauton_R...    Experimental
# 8   Rock__freemusiccharts.songs2012__2012-01-H._Zo...      Electronic
# 9                 Rock__diymAR06__10-Derek_Clegg-Judy            Rock
# 10                            Electronic__NS050__Lake    Experimental
# 11                         Electronic__mtk140__Csanca      Electronic
# 12                     Electronic__foot149__El_And_Eu            Rock
# 13            Electronic__nullbomb__spindrumlikeaboom      Electronic
# 14  Electronic__TFR100-VA-TornFleshRecordsPresents...    Experimental
# 15                        Electronic__MIXG031__Vozduh            Rock
# 16                         Electronic__pn037__Sabrina    Experimental
# 17  Electronic__mtcomp003__latatoo__secede_s_anoth...    Experimental
# 18                    Electronic__ffs104__The_Leather    Experimental
# 19                   Electronic__foot018__Baiao_Lo-fi    Experimental
# 20  Experimental__pcr089EmilDavydov-Sketches__Sket...            Rock
# 21  Experimental__PoodleplayArkestra-TheoryOfColou...    Experimental
# 22  Experimental__ca446_opa__04_-_Russian_State_Mu...            Rock
# 23       Experimental__AlbumInADayVol4__Summer_Breeze    Experimental
# 24                      Experimental__ca350_g__sh-dah    Experimental
# 25         Experimental__mz001_Mademoi_Selle__Himitsu            Rock
# 26  Experimental__tpd074__08_Grow_Up_Lamestream_Tu...    Experimental
# 27      Experimental__ca492_ai__Beautiful_Distraction    Experimental
# 28  Experimental__ca300_ca__206_-_Mons_Jacet_-_for...    Experimental
# 29                      Experimental__csr008__Say_Man      Electronic
# 30  Folk__lbn016Plusplus-gameOver__04_Plusplus_-_B...    Experimental
# 31  Folk__lbn007NickRivera-happySongIsAHappySong__...    Experimental
# 32  Folk__lbn017OldSplendifolia-utterlyHeartbreaki...    Experimental
# 33  Folk__EntertainmentForTheBraindead-Roadkillaaa...    Experimental
# 34  Folk__lclcb05DelgarmaDerAndrafolkWorldChanson_...            Rock
# 35                 Folk__pm007__The_Treeplanting_Song            Rock
# 36  Folk__pantoufle_tagada__I_Hope_You_re_Happy_Wi...      Electronic
# 37  Folk__DDW001__02_-_Built_From_Sticks_-_Here_co...            Folk
# 38                   Folk__ca201_meg__My_Orchard_Fire            Folk
# 39                         Folk__ekleipsi23__system_1    Experimental
# 40                          Hip-Hop__DWK123__Soul_Key         Hip-Hop
# 41                Hip-Hop__DWK031__Aydio_-_01_-_Track    Experimental
# 42            Hip-Hop__dystopiaq029__Times_re_Changin      Electronic
# 43               Hip-Hop__DWK149__Boogieman_Penthouse    Experimental
# 44                  Hip-Hop__mia049__lifelong_fiction    Experimental
# 45                      Hip-Hop__DWK217__Morning_Mist            Rock
# 46                   Hip-Hop__DWK301__Soul_Blue_Tango    Experimental
# 47                      Hip-Hop__DWK127__The_Werewolf    Experimental
# 48                        Hip-Hop__DWK315__Time2Spare    Experimental
# 49                        Hip-Hop__DWK155__Eazy_Livin      Electronic
#
#     main_score main_confidence_level  main_threshold_vote_count  \
# 0     0.565439              Moderate                          8
# 1     0.578539              Moderate                          8
# 2     0.612928              Moderate                          8
# 3     0.558755              Moderate                          8
# 4     0.481872       Low-to-moderate                          8
# 5     0.487924       Low-to-moderate                          8
# 6     0.546284              Moderate                          8
# 7     0.606244              Moderate                          8
# 8     0.630960              Moderate                          8
# 9     0.390207       Low-to-moderate                          8
# 10    0.468257       Low-to-moderate                          8
# 11    0.380607       Low-to-moderate                          6
# 12    0.389795       Low-to-moderate                          8
# 13    0.536827              Moderate                          8
# 14    0.776628                  High                          8
# 15    0.456272       Low-to-moderate                          8
# 16    0.561783              Moderate                          8
# 17    0.543909              Moderate                          8
# 18    0.562499              Moderate                          8
# 19    0.489454       Low-to-moderate                          8
# 20    0.439842       Low-to-moderate                          8
# 21    0.494070       Low-to-moderate                          8
# 22    0.410615       Low-to-moderate                          8
# 23    0.550025              Moderate                          8
# 24    0.565486              Moderate                          8
# 25    0.519981              Moderate                          8
# 26    0.532344              Moderate                          8
# 27    0.385706       Low-to-moderate                          8
# 28    0.702739                  High                          8
# 29    0.426806       Low-to-moderate                          8
# 30    0.434638       Low-to-moderate                          8
# 31    0.368926       Low-to-moderate                          8
# 32    0.462787       Low-to-moderate                          8
# 33    0.469050       Low-to-moderate                          8
# 34    0.476159       Low-to-moderate                          8
# 35    0.402734       Low-to-moderate                          8
# 36    0.687244              Moderate                          8
# 37    0.531868              Moderate                          7
# 38    0.587839              Moderate                          8
# 39    0.555550              Moderate                          8
# 40    0.366830       Low-to-moderate                          7
# 41    0.554200              Moderate                          8
# 42    0.465565       Low-to-moderate                          6
# 43    0.442799       Low-to-moderate                          8
# 44    0.491556       Low-to-moderate                          8
# 45    0.394960       Low-to-moderate                          7
# 46    0.441469       Low-to-moderate                          8
# 47    0.443956       Low-to-moderate                          8
# 48    0.620664              Moderate                          8
# 49    0.581886              Moderate                          8
#
#     main_top1_window_vote_count  main_top3_window_vote_count  \
# 0                             8                            8
# 1                             7                            8
# 2                             8                            8
# 3                             7                            8
# 4                             5                            8
# 5                             3                            8
# 6                             5                            8
# 7                             6                            8
# 8                             6                            7
# 9                             6                            7
# 10                            5                            8
# 11                            4                            6
# 12                            4                            7
# 13                            6                            8
# 14                            8                            8
# 15                            5                            8
# 16                            4                            8
# 17                            4                            8
# 18                            6                            8
# 19                            4                            8
# 20                            3                            8
# 21                            8                            8
# 22                            5                            8
# 23                            6                            8
# 24                            5                            8
# 25                            6                            8
# 26                            5                            7
# 27                            3                            7
# 28                            8                            8
# 29                            5                            8
# 30                            4                            6
# 31                            3                            8
# 32                            5                            8
# 33                            6                            8
# 34                            5                            8
# 35                            5                            8
# 36                            7                            8
# 37                            7                            7
# 38                            8                            8
# 39                            8                            8
# 40                            6                            6
# 41                            5                            8
# 42                            4                            7
# 43                            4                            8
# 44                            3                            8
# 45                            4                            8
# 46                            4                            8
# 47                            3                            8
# 48                            8                            8
# 49                            7                            8
#
#                              top3_genres  \
# 0                 Experimental|Rock|Folk
# 1           Experimental|Rock|Electronic
# 2           Experimental|Electronic|Rock
# 3           Experimental|Rock|Electronic
# 4                 Rock|Folk|Experimental
# 5                 Experimental|Rock|Folk
# 6           Experimental|Rock|Electronic
# 7           Experimental|Electronic|Rock
# 8           Electronic|Experimental|Rock
# 9                  Rock|Experimental|Pop
# 10                Experimental|Rock|Folk
# 11          Electronic|Experimental|Rock
# 12          Rock|Experimental|Electronic
# 13          Electronic|Experimental|Rock
# 14         Experimental|Electronic|Noise
# 15          Rock|Experimental|Electronic
# 16  Experimental|Electronic|Instrumental
# 17  Experimental|Electronic|Instrumental
# 18          Experimental|Rock|Electronic
# 19          Experimental|Electronic|Rock
# 20                Rock|Experimental|Folk
# 21        Experimental|Folk|Instrumental
# 22          Rock|Experimental|Electronic
# 23          Experimental|Electronic|Rock
# 24          Experimental|Rock|Electronic
# 25                Rock|Experimental|Folk
# 26          Experimental|Electronic|Rock
# 27                Experimental|Rock|Folk
# 28  Experimental|Electronic|Instrumental
# 29          Electronic|Experimental|Rock
# 30          Experimental|Electronic|Rock
# 31                Experimental|Folk|Rock
# 32                Experimental|Folk|Rock
# 33                Experimental|Folk|Rock
# 34                Rock|Experimental|Folk
# 35                Rock|Experimental|Folk
# 36       Electronic|Experimental|Hip-Hop
# 37                Folk|Rock|Experimental
# 38   Folk|Experimental|Singer-Songwriter
# 39          Experimental|Electronic|Rock
# 40       Hip-Hop|Electronic|Experimental
# 41          Experimental|Electronic|Rock
# 42       Electronic|Experimental|Hip-Hop
# 43          Experimental|Rock|Electronic
# 44          Experimental|Electronic|Rock
# 45          Rock|Experimental|Electronic
# 46          Experimental|Rock|Electronic
# 47       Experimental|Electronic|Hip-Hop
# 48          Experimental|Electronic|Rock
# 49               Electronic|Rock|Hip-Hop
#
#                                           top5_genres  low_confidence
# 0          Experimental|Rock|Folk|Improv|Instrumental           False
# 1        Experimental|Rock|Electronic|Avant-Garde|Pop           False
# 2      Experimental|Electronic|Rock|Avant-Garde|Noise           False
# 3       Experimental|Rock|Electronic|Punk|Avant-Garde           False
# 4        Rock|Folk|Experimental|Pop|Singer-Songwriter            True
# 5               Experimental|Rock|Folk|Electronic|Pop            True
# 6      Experimental|Rock|Electronic|Instrumental|Folk           False
# 7   Experimental|Electronic|Rock|Avant-Garde|Instr...           False
# 8   Electronic|Experimental|Rock|Instrumental|Hip-Hop           False
# 9               Rock|Experimental|Pop|Electronic|Folk            True
# 10            Experimental|Rock|Folk|Pop|Instrumental            True
# 11              Electronic|Experimental|Rock|Pop|Folk            True
# 12           Rock|Experimental|Electronic|Hip-Hop|Pop            True
# 13  Electronic|Experimental|Rock|Hip-Hop|Instrumental           False
# 14     Experimental|Electronic|Noise|Avant-Garde|Rock           False
# 15              Rock|Experimental|Electronic|Pop|Folk            True
# 16      Experimental|Electronic|Instrumental|Rock|Pop           False
# 17  Experimental|Electronic|Instrumental|Rock|Ambient           False
# 18   Experimental|Rock|Electronic|Avant-Garde|Hip-Hop           False
# 19  Experimental|Electronic|Rock|Hip-Hop|Instrumental            True
# 20     Rock|Experimental|Folk|Electronic|Instrumental            True
# 21     Experimental|Folk|Instrumental|Rock|Electronic            True
# 22              Rock|Experimental|Electronic|Pop|Punk            True
# 23     Experimental|Electronic|Rock|Instrumental|Folk           False
# 24     Experimental|Rock|Electronic|Punk|Instrumental           False
# 25             Rock|Experimental|Folk|Electronic|Punk           False
# 26  Experimental|Electronic|Rock|Hip-Hop|Instrumental           False
# 27       Experimental|Rock|Folk|Pop|Singer-Songwriter            True
# 28  Experimental|Electronic|Instrumental|Ambient|N...           False
# 29           Electronic|Experimental|Rock|Hip-Hop|Pop            True
# 30      Experimental|Electronic|Rock|Pop|Instrumental            True
# 31              Experimental|Folk|Rock|Pop|Electronic            True
# 32                   Experimental|Folk|Rock|Lo-Fi|Pop            True
# 33                   Experimental|Folk|Rock|Pop|Lo-Fi            True
# 34              Rock|Experimental|Folk|Pop|Electronic            True
# 35                    Rock|Experimental|Folk|Pop|Punk            True
# 36  Electronic|Experimental|Hip-Hop|Instrumental|Rock           False
# 37       Folk|Rock|Experimental|Singer-Songwriter|Pop           False
# 38       Folk|Experimental|Singer-Songwriter|Rock|Pop           False
# 39      Experimental|Electronic|Rock|Instrumental|Pop           False
# 40           Hip-Hop|Electronic|Experimental|Rock|Pop            True
# 41      Experimental|Electronic|Rock|Instrumental|Pop           False
# 42           Electronic|Experimental|Hip-Hop|Rock|Pop            True
# 43           Experimental|Rock|Electronic|Hip-Hop|Pop            True
# 44           Experimental|Electronic|Rock|Hip-Hop|Pop            True
# 45      Rock|Experimental|Electronic|Pop|Instrumental            True
# 46           Experimental|Rock|Electronic|Pop|Hip-Hop            True
# 47           Experimental|Electronic|Hip-Hop|Rock|Pop            True
# 48  Experimental|Electronic|Rock|Instrumental|Avan...           False
# 49           Electronic|Rock|Hip-Hop|Pop|Instrumental           False
# Top candidate rows:
#                                             song_name  \
# 0   Rock__ca200_cjazz__503._Andrij_Orel_-_Ringo_Qu...
# 1   Rock__ca200_cjazz__503._Andrij_Orel_-_Ringo_Qu...
# 2   Rock__ca200_cjazz__503._Andrij_Orel_-_Ringo_Qu...
# 3   Rock__ca200_cjazz__503._Andrij_Orel_-_Ringo_Qu...
# 4   Rock__ca200_cjazz__503._Andrij_Orel_-_Ringo_Qu...
# 5   Rock__ca200_cjazz__503._Andrij_Orel_-_Ringo_Qu...
# 6   Rock__ca200_cjazz__503._Andrij_Orel_-_Ringo_Qu...
# 7   Rock__ca200_cjazz__503._Andrij_Orel_-_Ringo_Qu...
# 8   Rock__ca200_cjazz__503._Andrij_Orel_-_Ringo_Qu...
# 9   Rock__ca200_cjazz__503._Andrij_Orel_-_Ringo_Qu...
# 10  Rock__ca200_cjazz__503._Andrij_Orel_-_Ringo_Qu...
# 11  Rock__ca200_cjazz__503._Andrij_Orel_-_Ringo_Qu...
# 12  Rock__ca200_cjazz__503._Andrij_Orel_-_Ringo_Qu...
# 13  Rock__ca200_cjazz__503._Andrij_Orel_-_Ringo_Qu...
# 14  Rock__ca200_cjazz__503._Andrij_Orel_-_Ringo_Qu...
# 15  Rock__afm004_allmyfaults_neonoir__The_course_o...
# 16  Rock__afm004_allmyfaults_neonoir__The_course_o...
# 17  Rock__afm004_allmyfaults_neonoir__The_course_o...
# 18  Rock__afm004_allmyfaults_neonoir__The_course_o...
# 19  Rock__afm004_allmyfaults_neonoir__The_course_o...
# 20  Rock__afm004_allmyfaults_neonoir__The_course_o...
# 21  Rock__afm004_allmyfaults_neonoir__The_course_o...
# 22  Rock__afm004_allmyfaults_neonoir__The_course_o...
# 23  Rock__afm004_allmyfaults_neonoir__The_course_o...
# 24  Rock__afm004_allmyfaults_neonoir__The_course_o...
# 25  Rock__afm004_allmyfaults_neonoir__The_course_o...
# 26  Rock__afm004_allmyfaults_neonoir__The_course_o...
# 27  Rock__afm004_allmyfaults_neonoir__The_course_o...
# 28  Rock__afm004_allmyfaults_neonoir__The_course_o...
# 29  Rock__afm004_allmyfaults_neonoir__The_course_o...
# 30              Rock__Lethargie.LP__Intro___Im_Herbst
# 31              Rock__Lethargie.LP__Intro___Im_Herbst
# 32              Rock__Lethargie.LP__Intro___Im_Herbst
# 33              Rock__Lethargie.LP__Intro___Im_Herbst
# 34              Rock__Lethargie.LP__Intro___Im_Herbst
# 35              Rock__Lethargie.LP__Intro___Im_Herbst
# 36              Rock__Lethargie.LP__Intro___Im_Herbst
# 37              Rock__Lethargie.LP__Intro___Im_Herbst
# 38              Rock__Lethargie.LP__Intro___Im_Herbst
# 39              Rock__Lethargie.LP__Intro___Im_Herbst
# 40              Rock__Lethargie.LP__Intro___Im_Herbst
# 41              Rock__Lethargie.LP__Intro___Im_Herbst
# 42              Rock__Lethargie.LP__Intro___Im_Herbst
# 43              Rock__Lethargie.LP__Intro___Im_Herbst
# 44              Rock__Lethargie.LP__Intro___Im_Herbst
# 45      Rock__Bostaurus.Demo__The_Sky_Full_of_Shadows
# 46      Rock__Bostaurus.Demo__The_Sky_Full_of_Shadows
# 47      Rock__Bostaurus.Demo__The_Sky_Full_of_Shadows
# 48      Rock__Bostaurus.Demo__The_Sky_Full_of_Shadows
# 49      Rock__Bostaurus.Demo__The_Sky_Full_of_Shadows
#
#                                            audio_path  genre_id       label  \
# 0   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        38    genre_38
# 1   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        12    genre_12
# 2   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        17    genre_17
# 3   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...       250   genre_250
# 4   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...      1235  genre_1235
# 5   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...         1     genre_1
# 6   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        15    genre_15
# 7   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...         4     genre_4
# 8   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...         5     genre_5
# 9   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        27    genre_27
# 10  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        18    genre_18
# 11  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        10    genre_10
# 12  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...         2     genre_2
# 13  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        25    genre_25
# 14  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        32    genre_32
# 15  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        38    genre_38
# 16  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        12    genre_12
# 17  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        15    genre_15
# 18  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...         1     genre_1
# 19  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        10    genre_10
# 20  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...      1235  genre_1235
# 21  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        32    genre_32
# 22  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        25    genre_25
# 23  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...       250   genre_250
# 24  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        41    genre_41
# 25  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        76    genre_76
# 26  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        17    genre_17
# 27  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...         2     genre_2
# 28  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        21    genre_21
# 29  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        27    genre_27
# 30  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        38    genre_38
# 31  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        15    genre_15
# 32  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        12    genre_12
# 33  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...         1     genre_1
# 34  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        32    genre_32
# 35  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...      1235  genre_1235
# 36  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        10    genre_10
# 37  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        41    genre_41
# 38  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...       250   genre_250
# 39  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        76    genre_76
# 40  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        21    genre_21
# 41  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        17    genre_17
# 42  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        25    genre_25
# 43  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...         2     genre_2
# 44  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        27    genre_27
# 45  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        38    genre_38
# 46  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        12    genre_12
# 47  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        15    genre_15
# 48  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...        25    genre_25
# 49  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...         1     genre_1
#
#           genre_name  mean_audio_score  max_audio_score confidence_level  \
# 0       Experimental          0.565439         0.701430         Moderate
# 1               Rock          0.265028         0.320544              Low
# 2               Folk          0.200406         0.291661              Low
# 3             Improv          0.199195         0.262492              Low
# 4       Instrumental          0.165079         0.282825              Low
# 5        Avant-Garde          0.132048         0.206623              Low
# 6         Electronic          0.111522         0.182365              Low
# 7               Jazz          0.101049         0.126601              Low
# 8          Classical          0.082545         0.170590              Low
# 9              Lo-Fi          0.079752         0.111832              Low
# 10        Soundtrack          0.076001         0.145006              Low
# 11               Pop          0.073223         0.100757              Low
# 12     International          0.070269         0.076258              Low
# 13              Punk          0.068048         0.094580              Low
# 14             Noise          0.065816         0.090880              Low
# 15      Experimental          0.578539         0.702917         Moderate
# 16              Rock          0.325567         0.481406  Low-to-moderate
# 17        Electronic          0.296563         0.391909              Low
# 18       Avant-Garde          0.133387         0.230010              Low
# 19               Pop          0.123368         0.194593              Low
# 20      Instrumental          0.105421         0.294798              Low
# 21             Noise          0.102522         0.125019              Low
# 22              Punk          0.098343         0.176424              Low
# 23            Improv          0.096572         0.179774              Low
# 24   Electroacoustic          0.083595         0.107466              Low
# 25  Experimental Pop          0.080348         0.106648              Low
# 26              Folk          0.076737         0.120032              Low
# 27     International          0.072634         0.090692              Low
# 28           Hip-Hop          0.068257         0.098551              Low
# 29             Lo-Fi          0.068038         0.085447              Low
# 30      Experimental          0.612928         0.660463         Moderate
# 31        Electronic          0.399678         0.472247  Low-to-moderate
# 32              Rock          0.270417         0.354200              Low
# 33       Avant-Garde          0.111470         0.132650              Low
# 34             Noise          0.109929         0.131543              Low
# 35      Instrumental          0.107245         0.153924              Low
# 36               Pop          0.102802         0.158523              Low
# 37   Electroacoustic          0.102081         0.117782              Low
# 38            Improv          0.071253         0.126750              Low
# 39  Experimental Pop          0.064881         0.084971              Low
# 40           Hip-Hop          0.060633         0.098464              Low
# 41              Folk          0.060449         0.112839              Low
# 42              Punk          0.054894         0.117300              Low
# 43     International          0.048180         0.054308              Low
# 44             Lo-Fi          0.047844         0.091010              Low
# 45      Experimental          0.558755         0.662007         Moderate
# 46              Rock          0.414183         0.569654  Low-to-moderate
# 47        Electronic          0.279063         0.347545              Low
# 48              Punk          0.165451         0.250627              Low
# 49       Avant-Garde          0.113199         0.159984              Low
#
#     threshold_vote_count  threshold_vote_rate  top1_window_vote_count  \
# 0                      8                1.000                       8
# 1                      7                0.875                       0
# 2                      4                0.500                       0
# 3                      4                0.500                       0
# 4                      2                0.250                       0
# 5                      1                0.125                       0
# 6                      0                0.000                       0
# 7                      0                0.000                       0
# 8                      0                0.000                       0
# 9                      0                0.000                       0
# 10                     0                0.000                       0
# 11                     0                0.000                       0
# 12                     0                0.000                       0
# 13                     0                0.000                       0
# 14                     0                0.000                       0
# 15                     8                1.000                       7
# 16                     6                0.750                       1
# 17                     7                0.875                       0
# 18                     1                0.125                       0
# 19                     0                0.000                       0
# 20                     1                0.125                       0
# 21                     0                0.000                       0
# 22                     0                0.000                       0
# 23                     0                0.000                       0
# 24                     0                0.000                       0
# 25                     0                0.000                       0
# 26                     0                0.000                       0
# 27                     0                0.000                       0
# 28                     0                0.000                       0
# 29                     0                0.000                       0
# 30                     8                1.000                       8
# 31                     8                1.000                       0
# 32                     8                1.000                       0
# 33                     0                0.000                       0
# 34                     0                0.000                       0
# 35                     0                0.000                       0
# 36                     0                0.000                       0
# 37                     0                0.000                       0
# 38                     0                0.000                       0
# 39                     0                0.000                       0
# 40                     0                0.000                       0
# 41                     0                0.000                       0
# 42                     0                0.000                       0
# 43                     0                0.000                       0
# 44                     0                0.000                       0
# 45                     8                1.000                       7
# 46                     8                1.000                       1
# 47                     8                1.000                       0
# 48                     1                0.125                       0
# 49                     0                0.000                       0
#
#     top3_window_vote_count  top5_window_vote_count  required_window_votes  \
# 0                        8                       8                      2
# 1                        7                       8                      2
# 2                        3                       6                      2
# 3                        4                       8                      2
# 4                        1                       6                      2
# 5                        1                       2                      2
# 6                        0                       2                      2
# 7                        0                       0                      2
# 8                        0                       0                      2
# 9                        0                       0                      2
# 10                       0                       0                      2
# 11                       0                       0                      2
# 12                       0                       0                      2
# 13                       0                       0                      2
# 14                       0                       0                      2
# 15                       8                       8                      2
# 16                       6                       8                      2
# 17                       7                       7                      2
# 18                       1                       5                      2
# 19                       0                       5                      2
# 20                       1                       1                      2
# 21                       0                       1                      2
# 22                       0                       2                      2
# 23                       0                       1                      2
# 24                       0                       0                      2
# 25                       0                       0                      2
# 26                       0                       0                      2
# 27                       0                       0                      2
# 28                       0                       0                      2
# 29                       0                       0                      2
# 30                       8                       8                      2
# 31                       8                       8                      2
# 32                       8                       8                      2
# 33                       0                       5                      2
# 34                       0                       5                      2
# 35                       0                       3                      2
# 36                       0                       2                      2
# 37                       0                       1                      2
# 38                       0                       0                      2
# 39                       0                       0                      2
# 40                       0                       0                      2
# 41                       0                       0                      2
# 42                       0                       0                      2
# 43                       0                       0                      2
# 44                       0                       0                      2
# 45                       8                       8                      2
# 46                       8                       8                      2
# 47                       7                       8                      2
# 48                       1                       7                      2
# 49                       0                       4                      2
#
#     stable_prediction                relationship_to_main
# 0                   1                       Primary genre
# 1                   1          Secondary associated genre
# 2                   1          Secondary associated genre
# 3                   0  Subgenre/child under primary genre
# 4                   0          Secondary associated genre
# 5                   0  Subgenre/child under primary genre
# 6                   0          Secondary associated genre
# 7                   0          Secondary associated genre
# 8                   0          Secondary associated genre
# 9                   0          Secondary associated genre
# 10                  0          Secondary associated genre
# 11                  0          Secondary associated genre
# 12                  0          Secondary associated genre
# 13                  0          Secondary associated genre
# 14                  0  Subgenre/child under primary genre
# 15                  1                       Primary genre
# 16                  1          Secondary associated genre
# 17                  1          Secondary associated genre
# 18                  0  Subgenre/child under primary genre
# 19                  0          Secondary associated genre
# 20                  0          Secondary associated genre
# 21                  0  Subgenre/child under primary genre
# 22                  0          Secondary associated genre
# 23                  0  Subgenre/child under primary genre
# 24                  0  Subgenre/child under primary genre
# 25                  0          Secondary associated genre
# 26                  0          Secondary associated genre
# 27                  0          Secondary associated genre
# 28                  0          Secondary associated genre
# 29                  0          Secondary associated genre
# 30                  1                       Primary genre
# 31                  1          Secondary associated genre
# 32                  1          Secondary associated genre
# 33                  0  Subgenre/child under primary genre
# 34                  0  Subgenre/child under primary genre
# 35                  0          Secondary associated genre
# 36                  0          Secondary associated genre
# 37                  0  Subgenre/child under primary genre
# 38                  0  Subgenre/child under primary genre
# 39                  0          Secondary associated genre
# 40                  0          Secondary associated genre
# 41                  0          Secondary associated genre
# 42                  0          Secondary associated genre
# 43                  0          Secondary associated genre
# 44                  0          Secondary associated genre
# 45                  1                       Primary genre
# 46                  1          Secondary associated genre
# 47                  1          Secondary associated genre
# 48                  0          Secondary associated genre
# 49                  0  Subgenre/child under primary genre
# Window-level predictions:
#                                             song_name  \
# 0   Rock__ca200_cjazz__503._Andrij_Orel_-_Ringo_Qu...
# 1   Rock__ca200_cjazz__503._Andrij_Orel_-_Ringo_Qu...
# 2   Rock__ca200_cjazz__503._Andrij_Orel_-_Ringo_Qu...
# 3   Rock__ca200_cjazz__503._Andrij_Orel_-_Ringo_Qu...
# 4   Rock__ca200_cjazz__503._Andrij_Orel_-_Ringo_Qu...
# 5   Rock__ca200_cjazz__503._Andrij_Orel_-_Ringo_Qu...
# 6   Rock__ca200_cjazz__503._Andrij_Orel_-_Ringo_Qu...
# 7   Rock__ca200_cjazz__503._Andrij_Orel_-_Ringo_Qu...
# 8   Rock__afm004_allmyfaults_neonoir__The_course_o...
# 9   Rock__afm004_allmyfaults_neonoir__The_course_o...
# 10  Rock__afm004_allmyfaults_neonoir__The_course_o...
# 11  Rock__afm004_allmyfaults_neonoir__The_course_o...
# 12  Rock__afm004_allmyfaults_neonoir__The_course_o...
# 13  Rock__afm004_allmyfaults_neonoir__The_course_o...
# 14  Rock__afm004_allmyfaults_neonoir__The_course_o...
# 15  Rock__afm004_allmyfaults_neonoir__The_course_o...
# 16              Rock__Lethargie.LP__Intro___Im_Herbst
# 17              Rock__Lethargie.LP__Intro___Im_Herbst
# 18              Rock__Lethargie.LP__Intro___Im_Herbst
# 19              Rock__Lethargie.LP__Intro___Im_Herbst
# 20              Rock__Lethargie.LP__Intro___Im_Herbst
# 21              Rock__Lethargie.LP__Intro___Im_Herbst
# 22              Rock__Lethargie.LP__Intro___Im_Herbst
# 23              Rock__Lethargie.LP__Intro___Im_Herbst
# 24      Rock__Bostaurus.Demo__The_Sky_Full_of_Shadows
# 25      Rock__Bostaurus.Demo__The_Sky_Full_of_Shadows
# 26      Rock__Bostaurus.Demo__The_Sky_Full_of_Shadows
# 27      Rock__Bostaurus.Demo__The_Sky_Full_of_Shadows
# 28      Rock__Bostaurus.Demo__The_Sky_Full_of_Shadows
# 29      Rock__Bostaurus.Demo__The_Sky_Full_of_Shadows
# 30      Rock__Bostaurus.Demo__The_Sky_Full_of_Shadows
# 31      Rock__Bostaurus.Demo__The_Sky_Full_of_Shadows
# 32                     Rock__BS450014__Last_Addiction
# 33                     Rock__BS450014__Last_Addiction
# 34                     Rock__BS450014__Last_Addiction
# 35                     Rock__BS450014__Last_Addiction
# 36                     Rock__BS450014__Last_Addiction
# 37                     Rock__BS450014__Last_Addiction
# 38                     Rock__BS450014__Last_Addiction
# 39                     Rock__BS450014__Last_Addiction
# 40  Rock__csr020__Set_The_Controls_For_the_Heart_o...
# 41  Rock__csr020__Set_The_Controls_For_the_Heart_o...
# 42  Rock__csr020__Set_The_Controls_For_the_Heart_o...
# 43  Rock__csr020__Set_The_Controls_For_the_Heart_o...
# 44  Rock__csr020__Set_The_Controls_For_the_Heart_o...
# 45  Rock__csr020__Set_The_Controls_For_the_Heart_o...
# 46  Rock__csr020__Set_The_Controls_For_the_Heart_o...
# 47  Rock__csr020__Set_The_Controls_For_the_Heart_o...
# 48              Rock__afm020_noctiflora_0407__Neorama
# 49              Rock__afm020_noctiflora_0407__Neorama
#
#                                            audio_path  window_index  \
# 0   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             0
# 1   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             1
# 2   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             2
# 3   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             3
# 4   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             4
# 5   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             5
# 6   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             6
# 7   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             7
# 8   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             0
# 9   E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             1
# 10  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             2
# 11  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             3
# 12  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             4
# 13  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             5
# 14  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             6
# 15  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             7
# 16  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             0
# 17  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             1
# 18  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             2
# 19  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             3
# 20  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             4
# 21  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             5
# 22  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             6
# 23  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             7
# 24  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             0
# 25  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             1
# 26  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             2
# 27  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             3
# 28  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             4
# 29  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             5
# 30  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             6
# 31  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             7
# 32  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             0
# 33  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             1
# 34  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             2
# 35  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             3
# 36  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             4
# 37  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             5
# 38  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             6
# 39  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             7
# 40  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             0
# 41  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             1
# 42  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             2
# 43  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             3
# 44  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             4
# 45  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             5
# 46  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             6
# 47  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             7
# 48  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             0
# 49  E:\SCHOOL\Masters\Capstone_FMA_Project\data\ex...             1
#
#     start_sample  start_second  end_second top1_label top1_genre_name  \
# 0              0          0.00       15.00   genre_38    Experimental
# 1        1262080         57.24       72.24   genre_38    Experimental
# 2        2524160        114.47      129.47   genre_38    Experimental
# 3        3786240        171.71      186.71   genre_38    Experimental
# 4        5048321        228.95      243.95   genre_38    Experimental
# 5        6310401        286.19      301.19   genre_38    Experimental
# 6        7572481        343.42      358.42   genre_38    Experimental
# 7        8834562        400.66      415.66   genre_38    Experimental
# 8              0          0.00       15.00   genre_38    Experimental
# 9        1049042         47.58       62.58   genre_38    Experimental
# 10       2098085         95.15      110.15   genre_12            Rock
# 11       3147127        142.73      157.73   genre_38    Experimental
# 12       4196170        190.30      205.30   genre_38    Experimental
# 13       5245212        237.88      252.88   genre_38    Experimental
# 14       6294255        285.45      300.45   genre_38    Experimental
# 15       7343298        333.03      348.03   genre_38    Experimental
# 16             0          0.00       15.00   genre_38    Experimental
# 17       1170990         53.11       68.11   genre_38    Experimental
# 18       2341980        106.21      121.21   genre_38    Experimental
# 19       3512970        159.32      174.32   genre_38    Experimental
# 20       4683960        212.42      227.42   genre_38    Experimental
# 21       5854950        265.53      280.53   genre_38    Experimental
# 22       7025940        318.64      333.64   genre_38    Experimental
# 23       8196930        371.74      386.74   genre_38    Experimental
# 24             0          0.00       15.00   genre_38    Experimental
# 25        593426         26.91       41.91   genre_38    Experimental
# 26       1186853         53.83       68.83   genre_38    Experimental
# 27       1780279         80.74       95.74   genre_38    Experimental
# 28       2373706        107.65      122.65   genre_12            Rock
# 29       2967132        134.56      149.56   genre_38    Experimental
# 30       3560559        161.48      176.48   genre_38    Experimental
# 31       4153986        188.39      203.39   genre_38    Experimental
# 32             0          0.00       15.00   genre_17            Folk
# 33        652441         29.59       44.59   genre_12            Rock
# 34       1304882         59.18       74.18   genre_12            Rock
# 35       1957324         88.77      103.77   genre_12            Rock
# 36       2609765        118.36      133.36   genre_17            Folk
# 37       3262207        147.95      162.95   genre_12            Rock
# 38       3914648        177.54      192.54   genre_12            Rock
# 39       4567090        207.12      222.12   genre_38    Experimental
# 40             0          0.00       15.00   genre_38    Experimental
# 41       1330459         60.34       75.34   genre_12            Rock
# 42       2660919        120.68      135.68   genre_12            Rock
# 43       3991379        181.01      196.01   genre_38    Experimental
# 44       5321838        241.35      256.35   genre_12            Rock
# 45       6652298        301.69      316.69   genre_12            Rock
# 46       7982758        362.03      377.03   genre_12            Rock
# ...
# 48                                         Time2Spare
# 49                                        Eazy Livin'
# 50                   01 - Monochromatic - Immobility-
# 51                                    05 - Doing Time
# 52                          Closer to You (feat. SHA)
# 53                               Heaven In Your Mouth
# 54                                            Falling
# 55                              The Virus Left Behind
# 56                                         Blue skies
# 57  09 - Universal Materials - This is the Macrophage
# 58                                            Runaway
# 59                           Mark Robinson - Cape May
#
#                                artist expected_primary_genre main_genre_name  \
# 0                             Various                   Rock    Experimental
# 1                       all:my:faults                   Rock    Experimental
# 2                           Lethargie                   Rock    Experimental
# 3                           Bostaurus                   Rock    Experimental
# 4                           Pete Lund                   Rock            Rock
# 5                     Various Artists                   Rock    Experimental
# 6                          Noctiflora                   Rock    Experimental
# 7                          Tigerberry                   Rock    Experimental
# 8                                 NaN                   Rock      Electronic
# 9                         Derek Clegg                   Rock            Rock
# 10                 No-Source Netlabel             Electronic    Experimental
# 11                                 ST             Electronic      Electronic
# 12                    Edmar Travassos             Electronic            Rock
# 13                                NaN             Electronic      Electronic
# 14                 Torn Flesh Records             Electronic    Experimental
# 15                                NaN             Electronic            Rock
# 16                    Francisco Pinto             Electronic    Experimental
# 17                                NaN             Electronic    Experimental
# 18                     Antuan Graftio             Electronic    Experimental
# 19     Chico Correa & Electronic Band             Electronic    Experimental
# 20                         E. Davydov           Experimental            Rock
# 21                Poodleplay Arkestra           Experimental    Experimental
# 22                               Opa!           Experimental            Rock
# 23                    various artists           Experimental    Experimental
# 24                         gillicuddy           Experimental    Experimental
# 25                      Mademoi Selle           Experimental            Rock
# 26                     Andrew Cauthen           Experimental    Experimental
# 27                      Arcade Island           Experimental    Experimental
# 28                            Various           Experimental    Experimental
# 29                    R. Stevie Moore           Experimental      Electronic
# 30                                NaN                   Folk    Experimental
# 31                        Nick Rivera                   Folk    Experimental
# 32                                NaN                   Folk    Experimental
# 33                     Julia Kotowski                   Folk    Experimental
# 34                                NaN                   Folk            Rock
# 35                                 PK                   Folk            Rock
# 36                                NaN                   Folk      Electronic
# 37                                NaN                   Folk            Folk
# 38                 Menhirs of Er Grah                   Folk            Folk
# 39                    Various Artists                   Folk    Experimental
# 40                           ProleteR                Hip-Hop         Hip-Hop
# 41                              Aydio                Hip-Hop    Experimental
# 42                    Various Artists                Hip-Hop      Electronic
# 43                    Boogie Belgique                Hip-Hop    Experimental
# 44                                NaN                Hip-Hop    Experimental
# 45                    Boogie Belgique                Hip-Hop            Rock
# 46                            Mounika                Hip-Hop    Experimental
# 47                               Kova                Hip-Hop    Experimental
# 48                             Anitek                Hip-Hop    Experimental
# 49                           Poldoore                Hip-Hop      Electronic
# 50                      MonoChromatic                    Pop      Electronic
# 51                           Garmisch                    Pop    Experimental
# 52                         starfrosch                    Pop      Electronic
# 53                            intouch                    Pop    Experimental
# 54                            Twizzle                    Pop    Experimental
# 55                      James Gardner                    Pop    Experimental
# 56  Bjorn Kleinhenz and Pete Thompson                    Pop    Experimental
# 57                   Michael Gregoire                    Pop    Experimental
# 58                                NaN                    Pop    Experimental
# 59          My Mean Magpie Recordings                    Pop    Experimental
#
#     main_score  top1_hit  top3_hit  top5_hit  stable_prediction_hit  \
# 0     0.565439     False      True      True                   True
# 1     0.578539     False      True      True                   True
# 2     0.612928     False      True      True                   True
# 3     0.558755     False      True      True                   True
# 4     0.481872      True      True      True                   True
# 5     0.487924     False      True      True                   True
# 6     0.546284     False      True      True                   True
# 7     0.606244     False      True      True                   True
# 8     0.630960     False      True      True                   True
# 9     0.390207      True      True      True                   True
# 10    0.468257     False     False     False                  False
# 11    0.380607      True      True      True                   True
# 12    0.389795     False      True      True                   True
# 13    0.536827      True      True      True                   True
# 14    0.776628     False      True      True                   True
# 15    0.456272     False      True      True                   True
# 16    0.561783     False      True      True                   True
# 17    0.543909     False      True      True                   True
# 18    0.562499     False      True      True                   True
# 19    0.489454     False      True      True                   True
# 20    0.439842     False      True      True                   True
# 21    0.494070      True      True      True                   True
# 22    0.410615     False      True      True                   True
# 23    0.550025      True      True      True                   True
# 24    0.565486      True      True      True                   True
# 25    0.519981     False      True      True                   True
# 26    0.532344      True      True      True                   True
# 27    0.385706      True      True      True                   True
# 28    0.702739      True      True      True                   True
# 29    0.426806     False      True      True                   True
# 30    0.434638     False     False     False                  False
# 31    0.368926     False      True      True                   True
# 32    0.462787     False      True      True                   True
# 33    0.469050     False      True      True                   True
# 34    0.476159     False      True      True                   True
# 35    0.402734     False      True      True                   True
# 36    0.687244     False     False     False                  False
# 37    0.531868      True      True      True                   True
# 38    0.587839      True      True      True                   True
# 39    0.555550     False     False     False                  False
# 40    0.366830      True      True      True                   True
# 41    0.554200     False     False     False                  False
# 42    0.465565     False      True      True                   True
# 43    0.442799     False     False      True                  False
# 44    0.491556     False     False      True                  False
# 45    0.394960     False     False     False                  False
# 46    0.441469     False     False      True                  False
# 47    0.443956     False      True      True                   True
# 48    0.620664     False     False     False                  False
# 49    0.581886     False      True      True                   True
# 50    0.424461     False     False      True                  False
# 51    0.504474     False     False      True                  False
# 52    0.659494     False     False      True                  False
# 53    0.558473     False     False      True                  False
# 54    0.520471     False     False      True                  False
# 55    0.545824     False     False      True                  False
# 56    0.551967     False     False     False                  False
# 57    0.485410     False     False      True                  False
# 58    0.524945     False     False     False                  False
# 59    0.498985     False     False     False                  False
#
#                              top3_genres  \
# 0                 Experimental|Rock|Folk
# 1           Experimental|Rock|Electronic
# 2           Experimental|Electronic|Rock
# 3           Experimental|Rock|Electronic
# 4                 Rock|Folk|Experimental
# 5                 Experimental|Rock|Folk
# 6           Experimental|Rock|Electronic
# 7           Experimental|Electronic|Rock
# 8           Electronic|Experimental|Rock
# 9                  Rock|Experimental|Pop
# 10                Experimental|Rock|Folk
# 11          Electronic|Experimental|Rock
# 12          Rock|Experimental|Electronic
# 13          Electronic|Experimental|Rock
# 14         Experimental|Electronic|Noise
# 15          Rock|Experimental|Electronic
# 16  Experimental|Electronic|Instrumental
# 17  Experimental|Electronic|Instrumental
# 18          Experimental|Rock|Electronic
# 19          Experimental|Electronic|Rock
# 20                Rock|Experimental|Folk
# 21        Experimental|Folk|Instrumental
# 22          Rock|Experimental|Electronic
# 23          Experimental|Electronic|Rock
# 24          Experimental|Rock|Electronic
# 25                Rock|Experimental|Folk
# 26          Experimental|Electronic|Rock
# 27                Experimental|Rock|Folk
# 28  Experimental|Electronic|Instrumental
# 29          Electronic|Experimental|Rock
# 30          Experimental|Electronic|Rock
# 31                Experimental|Folk|Rock
# 32                Experimental|Folk|Rock
# 33                Experimental|Folk|Rock
# 34                Rock|Experimental|Folk
# 35                Rock|Experimental|Folk
# 36       Electronic|Experimental|Hip-Hop
# 37                Folk|Rock|Experimental
# 38   Folk|Experimental|Singer-Songwriter
# 39          Experimental|Electronic|Rock
# 40       Hip-Hop|Electronic|Experimental
# 41          Experimental|Electronic|Rock
# 42       Electronic|Experimental|Hip-Hop
# 43          Experimental|Rock|Electronic
# 44          Experimental|Electronic|Rock
# 45          Rock|Experimental|Electronic
# 46          Experimental|Rock|Electronic
# 47       Experimental|Electronic|Hip-Hop
# 48          Experimental|Electronic|Rock
# 49               Electronic|Rock|Hip-Hop
# 50       Electronic|Experimental|Hip-Hop
# 51          Experimental|Rock|Electronic
# 52       Electronic|Hip-Hop|Experimental
# 53          Experimental|Rock|Electronic
# 54                Experimental|Rock|Folk
# 55                Experimental|Rock|Folk
# 56          Experimental|Rock|Electronic
# 57          Experimental|Electronic|Rock
# 58          Experimental|Rock|Electronic
# 59                Experimental|Rock|Punk
#
#                                           top5_genres
# 0          Experimental|Rock|Folk|Improv|Instrumental
# 1        Experimental|Rock|Electronic|Avant-Garde|Pop
# 2      Experimental|Electronic|Rock|Avant-Garde|Noise
# 3       Experimental|Rock|Electronic|Punk|Avant-Garde
# 4        Rock|Folk|Experimental|Pop|Singer-Songwriter
# 5               Experimental|Rock|Folk|Electronic|Pop
# 6      Experimental|Rock|Electronic|Instrumental|Folk
# 7   Experimental|Electronic|Rock|Avant-Garde|Instr...
# 8   Electronic|Experimental|Rock|Instrumental|Hip-Hop
# 9               Rock|Experimental|Pop|Electronic|Folk
# 10            Experimental|Rock|Folk|Pop|Instrumental
# 11              Electronic|Experimental|Rock|Pop|Folk
# 12           Rock|Experimental|Electronic|Hip-Hop|Pop
# 13  Electronic|Experimental|Rock|Hip-Hop|Instrumental
# 14     Experimental|Electronic|Noise|Avant-Garde|Rock
# 15              Rock|Experimental|Electronic|Pop|Folk
# 16      Experimental|Electronic|Instrumental|Rock|Pop
# 17  Experimental|Electronic|Instrumental|Rock|Ambient
# 18   Experimental|Rock|Electronic|Avant-Garde|Hip-Hop
# 19  Experimental|Electronic|Rock|Hip-Hop|Instrumental
# 20     Rock|Experimental|Folk|Electronic|Instrumental
# 21     Experimental|Folk|Instrumental|Rock|Electronic
# 22              Rock|Experimental|Electronic|Pop|Punk
# 23     Experimental|Electronic|Rock|Instrumental|Folk
# 24     Experimental|Rock|Electronic|Punk|Instrumental
# 25             Rock|Experimental|Folk|Electronic|Punk
# 26  Experimental|Electronic|Rock|Hip-Hop|Instrumental
# 27       Experimental|Rock|Folk|Pop|Singer-Songwriter
# 28  Experimental|Electronic|Instrumental|Ambient|N...
# 29           Electronic|Experimental|Rock|Hip-Hop|Pop
# 30      Experimental|Electronic|Rock|Pop|Instrumental
# 31              Experimental|Folk|Rock|Pop|Electronic
# 32                   Experimental|Folk|Rock|Lo-Fi|Pop
# 33                   Experimental|Folk|Rock|Pop|Lo-Fi
# 34              Rock|Experimental|Folk|Pop|Electronic
# 35                    Rock|Experimental|Folk|Pop|Punk
# 36  Electronic|Experimental|Hip-Hop|Instrumental|Rock
# 37       Folk|Rock|Experimental|Singer-Songwriter|Pop
# 38       Folk|Experimental|Singer-Songwriter|Rock|Pop
# 39      Experimental|Electronic|Rock|Instrumental|Pop
# 40           Hip-Hop|Electronic|Experimental|Rock|Pop
# 41      Experimental|Electronic|Rock|Instrumental|Pop
# 42           Electronic|Experimental|Hip-Hop|Rock|Pop
# 43           Experimental|Rock|Electronic|Hip-Hop|Pop
# 44           Experimental|Electronic|Rock|Hip-Hop|Pop
# 45      Rock|Experimental|Electronic|Pop|Instrumental
# 46           Experimental|Rock|Electronic|Pop|Hip-Hop
# 47           Experimental|Electronic|Hip-Hop|Rock|Pop
# 48  Experimental|Electronic|Rock|Instrumental|Avan...
# 49           Electronic|Rock|Hip-Hop|Pop|Instrumental
# 50           Electronic|Experimental|Hip-Hop|Rock|Pop
# 51      Experimental|Rock|Electronic|Pop|Instrumental
# 52           Electronic|Hip-Hop|Experimental|Rock|Pop
# 53      Experimental|Rock|Electronic|Pop|Instrumental
# 54              Experimental|Rock|Folk|Electronic|Pop
# 55              Experimental|Rock|Folk|Electronic|Pop
# 56      Experimental|Rock|Electronic|Folk|Avant-Garde
# 57           Experimental|Electronic|Rock|Hip-Hop|Pop
# 58      Experimental|Rock|Electronic|Avant-Garde|Folk
# 59           Experimental|Rock|Punk|Avant-Garde|Lo-Fi

# %% [markdown]
# ## How to Report Notebook 50
#
# Notebook 50 should be described as a deployment-style external-audio experiment, not the formal benchmark.
#
# Suggested wording:
#
# > Notebook 50 applies the trained audio candidate-150 model to complete external songs. Each song is split into multiple 15-second windows, each window is scored by the model, and song-level predictions are produced by averaging genre confidence across windows while also reporting how often each genre appears across the windows. This supports a recommendation-style interpretation using Top-1, Top-3, and Top-5 candidate genres.
#
# Important caveat:
#
# - Notebook 49 is the formal held-out FMA evaluation.
# - Notebook 50 is a practical deployment test for complete songs and may experience domain shift from commercial/external audio.
#
#
# With the external manifest enabled, report Top-1, Top-3, and Top-5 hit rates against the `acceptable_labels` column. This is stronger than exact-name matching because many songs have valid subgenre/parent genre alternatives.
